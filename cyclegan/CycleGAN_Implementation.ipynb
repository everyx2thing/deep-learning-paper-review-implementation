# %% [markdown]
# #LAB 7: CycleGAN
#
# <h4><div style="text-align: right"> Due date: 23:59 Dec 9, 2025.  </div> <br>
# <div style="text-align: right"> Please upload your file and final-report at PLATO before the class in the form of [ID_Name_Lab7.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - Each team must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[Insert your ID HERE] [Insert your name HERE]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2025-12-03 11:21:30.961806

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p "/content/dataset/lab7"
# !tar -xvf "/content/drive/MyDrive/lab7.tar" -C "/content/dataset/lab7"
# Out:
# Streaming output truncated to the last 5000 lines.
# edges2shoes/train/train/5681_AB.jpg
# edges2shoes/train/train/5682_AB.jpg
# edges2shoes/train/train/5683_AB.jpg
# edges2shoes/train/train/5684_AB.jpg
# edges2shoes/train/train/5685_AB.jpg
# edges2shoes/train/train/5686_AB.jpg
# edges2shoes/train/train/5687_AB.jpg
# edges2shoes/train/train/5688_AB.jpg
# edges2shoes/train/train/5689_AB.jpg
# edges2shoes/train/train/568_AB.jpg
# edges2shoes/train/train/5690_AB.jpg
# edges2shoes/train/train/5691_AB.jpg
# edges2shoes/train/train/5692_AB.jpg
# edges2shoes/train/train/5693_AB.jpg
# edges2shoes/train/train/5694_AB.jpg
# edges2shoes/train/train/5695_AB.jpg
# edges2shoes/train/train/5696_AB.jpg
# edges2shoes/train/train/5697_AB.jpg
# edges2shoes/train/train/5698_AB.jpg
# edges2shoes/train/train/5699_AB.jpg
# edges2shoes/train/train/569_AB.jpg
# edges2shoes/train/train/56_AB.jpg
# edges2shoes/train/train/5700_AB.jpg
# edges2shoes/train/train/5701_AB.jpg
# edges2shoes/train/train/5702_AB.jpg
# edges2shoes/train/train/5703_AB.jpg
# edges2shoes/train/train/5704_AB.jpg
# edges2shoes/train/train/5705_AB.jpg
# edges2shoes/train/train/5706_AB.jpg
# edges2shoes/train/train/5707_AB.jpg
# edges2shoes/train/train/5708_AB.jpg
# edges2shoes/train/train/5709_AB.jpg
# edges2shoes/train/train/570_AB.jpg
# edges2shoes/train/train/5710_AB.jpg
# edges2shoes/train/train/5711_AB.jpg
# edges2shoes/train/train/5712_AB.jpg
# edges2shoes/train/train/5713_AB.jpg
# edges2shoes/train/train/5714_AB.jpg
# edges2shoes/train/train/5715_AB.jpg
# edges2shoes/train/train/5716_AB.jpg
# edges2shoes/train/train/5717_AB.jpg
# edges2shoes/train/train/5718_AB.jpg
# edges2shoes/train/train/5719_AB.jpg
# edges2shoes/train/train/571_AB.jpg
# edges2shoes/train/train/5720_AB.jpg
# edges2shoes/train/train/5721_AB.jpg
# edges2shoes/train/train/5722_AB.jpg
# edges2shoes/train/train/5723_AB.jpg
# edges2shoes/train/train/5978_AB.jpg
# edges2shoes/train/train/5979_AB.jpg
# edges2shoes/train/train/597_AB.jpg
# edges2shoes/train/train/5980_AB.jpg
# edges2shoes/train/train/5981_AB.jpg
# edges2shoes/train/train/5982_AB.jpg
# edges2shoes/train/train/5983_AB.jpg
# edges2shoes/train/train/5984_AB.jpg
# edges2shoes/train/train/5985_AB.jpg
# edges2shoes/train/train/5986_AB.jpg
# edges2shoes/train/train/5987_AB.jpg
# edges2shoes/train/train/5988_AB.jpg
# edges2shoes/train/train/5989_AB.jpg
# edges2shoes/train/train/598_AB.jpg
# edges2shoes/train/train/5990_AB.jpg
# edges2shoes/train/train/5991_AB.jpg
# edges2shoes/train/train/5992_AB.jpg
# edges2shoes/train/train/5993_AB.jpg
# edges2shoes/train/train/5994_AB.jpg
# edges2shoes/train/train/5995_AB.jpg
# edges2shoes/train/train/5996_AB.jpg
# edges2shoes/train/train/5997_AB.jpg
# edges2shoes/train/train/5998_AB.jpg
# edges2shoes/train/train/5999_AB.jpg
# edges2shoes/train/train/599_AB.jpg
# edges2shoes/train/train/59_AB.jpg
# edges2shoes/train/train/5_AB.jpg
# edges2shoes/train/train/6000_AB.jpg
# edges2shoes/train/train/6001_AB.jpg
# edges2shoes/train/train/6002_AB.jpg
# edges2shoes/train/train/6003_AB.jpg
# edges2shoes/train/train/6004_AB.jpg
# edges2shoes/train/train/6005_AB.jpg
# edges2shoes/train/train/6006_AB.jpg
# edges2shoes/train/train/6007_AB.jpg
# edges2shoes/train/train/6008_AB.jpg
# edges2shoes/train/train/6009_AB.jpg
# edges2shoes/train/train/600_AB.jpg
# edges2shoes/train/train/6010_AB.jpg
# edges2shoes/train/train/6011_AB.jpg
# edges2shoes/train/train/6012_AB.jpg
# edges2shoes/train/train/6013_AB.jpg
# edges2shoes/train/train/6014_AB.jpg
# edges2shoes/train/train/6015_AB.jpg
# edges2shoes/train/train/6016_AB.jpg
# edges2shoes/train/train/6017_AB.jpg
# edges2shoes/train/train/6018_AB.jpg
# edges2shoes/train/train/6019_AB.jpg
# edges2shoes/train/train/601_AB.jpg
# edges2shoes/train/train/6020_AB.jpg
# edges2shoes/train/train/6021_AB.jpg
# edges2shoes/train/train/6022_AB.jpg
# edges2shoes/train/train/6023_AB.jpg
# edges2shoes/train/train/6024_AB.jpg
# edges2shoes/train/train/6025_AB.jpg
# edges2shoes/train/train/6026_AB.jpg
# edges2shoes/train/train/6027_AB.jpg
# edges2shoes/train/train/6028_AB.jpg
# edges2shoes/train/train/6029_AB.jpg
# edges2shoes/train/train/602_AB.jpg
# edges2shoes/train/train/6030_AB.jpg
# edges2shoes/train/train/6031_AB.jpg
# edges2shoes/train/train/6032_AB.jpg
# edges2shoes/train/train/6033_AB.jpg
# edges2shoes/train/train/6034_AB.jpg
# edges2shoes/train/train/6035_AB.jpg
# edges2shoes/train/train/6036_AB.jpg
# edges2shoes/train/train/6037_AB.jpg
# edges2shoes/train/train/6038_AB.jpg
# edges2shoes/train/train/6039_AB.jpg
# edges2shoes/train/train/603_AB.jpg
# edges2shoes/train/train/6040_AB.jpg
# edges2shoes/train/train/6041_AB.jpg
# edges2shoes/train/train/6042_AB.jpg
# edges2shoes/train/train/6043_AB.jpg
# edges2shoes/train/train/6044_AB.jpg
# edges2shoes/train/train/6045_AB.jpg
# edges2shoes/train/train/6046_AB.jpg
# edges2shoes/train/train/6047_AB.jpg
# edges2shoes/train/train/6048_AB.jpg
# edges2shoes/train/train/6049_AB.jpg
# edges2shoes/train/train/604_AB.jpg
# edges2shoes/train/train/6050_AB.jpg
# edges2shoes/train/train/6051_AB.jpg
# edges2shoes/train/train/6052_AB.jpg
# edges2shoes/train/train/6053_AB.jpg
# edges2shoes/train/train/6054_AB.jpg
# edges2shoes/train/train/6055_AB.jpg
# edges2shoes/train/train/6056_AB.jpg
# edges2shoes/train/train/6057_AB.jpg
# edges2shoes/train/train/6058_AB.jpg
# edges2shoes/train/train/6059_AB.jpg
# edges2shoes/train/train/605_AB.jpg
# edges2shoes/train/train/6060_AB.jpg
# edges2shoes/train/train/6061_AB.jpg
# edges2shoes/train/train/6062_AB.jpg
# edges2shoes/train/train/6063_AB.jpg
# edges2shoes/train/train/6064_AB.jpg
# edges2shoes/train/train/6065_AB.jpg
# edges2shoes/train/train/6066_AB.jpg
# edges2shoes/train/train/6067_AB.jpg
# edges2shoes/train/train/6068_AB.jpg
# edges2shoes/train/train/6069_AB.jpg
# edges2shoes/train/train/606_AB.jpg
# edges2shoes/train/train/6070_AB.jpg
# edges2shoes/train/train/6071_AB.jpg
# edges2shoes/train/train/6072_AB.jpg
# edges2shoes/train/train/6073_AB.jpg
# edges2shoes/train/train/6074_AB.jpg
# edges2shoes/train/train/6075_AB.jpg
# edges2shoes/train/train/6076_AB.jpg
# edges2shoes/train/train/6077_AB.jpg
# edges2shoes/train/train/6078_AB.jpg
# edges2shoes/train/train/6079_AB.jpg
# edges2shoes/train/train/607_AB.jpg
# edges2shoes/train/train/6080_AB.jpg
# edges2shoes/train/train/6081_AB.jpg
# edges2shoes/train/train/6082_AB.jpg
# edges2shoes/train/train/6083_AB.jpg
# edges2shoes/train/train/6084_AB.jpg
# edges2shoes/train/train/6085_AB.jpg
# edges2shoes/train/train/6086_AB.jpg
# edges2shoes/train/train/6087_AB.jpg
# edges2shoes/train/train/6088_AB.jpg
# edges2shoes/train/train/6089_AB.jpg
# edges2shoes/train/train/608_AB.jpg
# edges2shoes/train/train/6090_AB.jpg
# edges2shoes/train/train/6091_AB.jpg
# edges2shoes/train/train/6092_AB.jpg
# edges2shoes/train/train/6093_AB.jpg
# edges2shoes/train/train/6094_AB.jpg
# edges2shoes/train/train/6095_AB.jpg
# edges2shoes/train/train/6096_AB.jpg
# edges2shoes/train/train/6097_AB.jpg
# edges2shoes/train/train/6098_AB.jpg
# edges2shoes/train/train/6099_AB.jpg
# edges2shoes/train/train/609_AB.jpg
# edges2shoes/train/train/60_AB.jpg
# edges2shoes/train/train/6100_AB.jpg
# edges2shoes/train/train/6101_AB.jpg
# edges2shoes/train/train/6102_AB.jpg
# edges2shoes/train/train/6103_AB.jpg
# edges2shoes/train/train/6104_AB.jpg
# edges2shoes/train/train/6105_AB.jpg
# edges2shoes/train/train/6106_AB.jpg
# edges2shoes/train/train/6107_AB.jpg
# edges2shoes/train/train/6108_AB.jpg
# edges2shoes/train/train/6109_AB.jpg
# edges2shoes/train/train/610_AB.jpg
# edges2shoes/train/train/6110_AB.jpg
# edges2shoes/train/train/6111_AB.jpg
# edges2shoes/train/train/6112_AB.jpg
# edges2shoes/train/train/6113_AB.jpg
# edges2shoes/train/train/6114_AB.jpg
# edges2shoes/train/train/6115_AB.jpg
# edges2shoes/train/train/6116_AB.jpg
# edges2shoes/train/train/6117_AB.jpg
# edges2shoes/train/train/6118_AB.jpg
# edges2shoes/train/train/6119_AB.jpg
# edges2shoes/train/train/611_AB.jpg
# edges2shoes/train/train/6120_AB.jpg
# edges2shoes/train/train/6121_AB.jpg
# edges2shoes/train/train/6122_AB.jpg
# edges2shoes/train/train/6123_AB.jpg
# edges2shoes/train/train/6124_AB.jpg
# edges2shoes/train/train/6125_AB.jpg
# edges2shoes/train/train/6126_AB.jpg
# edges2shoes/train/train/6127_AB.jpg
# edges2shoes/train/train/6128_AB.jpg
# edges2shoes/train/train/6129_AB.jpg
# edges2shoes/train/train/612_AB.jpg
# edges2shoes/train/train/6130_AB.jpg
# edges2shoes/train/train/6131_AB.jpg
# edges2shoes/train/train/6132_AB.jpg
# edges2shoes/train/train/6133_AB.jpg
# edges2shoes/train/train/6134_AB.jpg
# edges2shoes/train/train/6135_AB.jpg
# edges2shoes/train/train/6136_AB.jpg
# edges2shoes/train/train/6137_AB.jpg
# edges2shoes/train/train/6138_AB.jpg
# edges2shoes/train/train/6139_AB.jpg
# edges2shoes/train/train/613_AB.jpg
# edges2shoes/train/train/6140_AB.jpg
# edges2shoes/train/train/6141_AB.jpg
# edges2shoes/train/train/6142_AB.jpg
# edges2shoes/train/train/6143_AB.jpg
# edges2shoes/train/train/6144_AB.jpg
# edges2shoes/train/train/6145_AB.jpg
# edges2shoes/train/train/6146_AB.jpg
# edges2shoes/train/train/6147_AB.jpg
# edges2shoes/train/train/6148_AB.jpg
# edges2shoes/train/train/6149_AB.jpg
# edges2shoes/train/train/614_AB.jpg
# edges2shoes/train/train/6150_AB.jpg
# edges2shoes/train/train/6151_AB.jpg
# edges2shoes/train/train/6152_AB.jpg
# edges2shoes/train/train/6153_AB.jpg
# edges2shoes/train/train/6154_AB.jpg
# edges2shoes/train/train/6155_AB.jpg
# edges2shoes/train/train/6156_AB.jpg
# edges2shoes/train/train/6157_AB.jpg
# edges2shoes/train/train/6158_AB.jpg
# edges2shoes/train/train/6159_AB.jpg
# edges2shoes/train/train/615_AB.jpg
# edges2shoes/train/train/6160_AB.jpg
# edges2shoes/train/train/6161_AB.jpg
# edges2shoes/train/train/6162_AB.jpg
# edges2shoes/train/train/6163_AB.jpg
# edges2shoes/train/train/6164_AB.jpg
# edges2shoes/train/train/6165_AB.jpg
# edges2shoes/train/train/6166_AB.jpg
# edges2shoes/train/train/6167_AB.jpg
# edges2shoes/train/train/6168_AB.jpg
# edges2shoes/train/train/6169_AB.jpg
# edges2shoes/train/train/616_AB.jpg
# edges2shoes/train/train/6170_AB.jpg
# edges2shoes/train/train/6171_AB.jpg
# edges2shoes/train/train/6172_AB.jpg
# edges2shoes/train/train/6173_AB.jpg
# edges2shoes/train/train/6174_AB.jpg
# edges2shoes/train/train/6175_AB.jpg
# edges2shoes/train/train/6176_AB.jpg
# edges2shoes/train/train/6177_AB.jpg
# edges2shoes/train/train/6178_AB.jpg
# edges2shoes/train/train/6179_AB.jpg
# edges2shoes/train/train/617_AB.jpg
# edges2shoes/train/train/6180_AB.jpg
# edges2shoes/train/train/6181_AB.jpg
# edges2shoes/train/train/6182_AB.jpg
# edges2shoes/train/train/6183_AB.jpg
# edges2shoes/train/train/6184_AB.jpg
# edges2shoes/train/train/6185_AB.jpg
# edges2shoes/train/train/6186_AB.jpg
# edges2shoes/train/train/6187_AB.jpg
# edges2shoes/train/train/6188_AB.jpg
# edges2shoes/train/train/6189_AB.jpg
# edges2shoes/train/train/618_AB.jpg
# edges2shoes/train/train/6190_AB.jpg
# edges2shoes/train/train/6191_AB.jpg
# edges2shoes/train/train/6192_AB.jpg
# edges2shoes/train/train/6193_AB.jpg
# edges2shoes/train/train/6194_AB.jpg
# edges2shoes/train/train/6195_AB.jpg
# edges2shoes/train/train/6196_AB.jpg
# edges2shoes/train/train/6197_AB.jpg
# edges2shoes/train/train/6198_AB.jpg
# edges2shoes/train/train/6199_AB.jpg
# edges2shoes/train/train/619_AB.jpg
# edges2shoes/train/train/61_AB.jpg
# edges2shoes/train/train/6200_AB.jpg
# edges2shoes/train/train/6201_AB.jpg
# edges2shoes/train/train/6202_AB.jpg
# edges2shoes/train/train/6203_AB.jpg
# edges2shoes/train/train/6204_AB.jpg
# edges2shoes/train/train/6205_AB.jpg
# edges2shoes/train/train/6206_AB.jpg
# edges2shoes/train/train/6207_AB.jpg
# edges2shoes/train/train/6208_AB.jpg
# edges2shoes/train/train/6209_AB.jpg
# edges2shoes/train/train/620_AB.jpg
# edges2shoes/train/train/6210_AB.jpg
# edges2shoes/train/train/6211_AB.jpg
# edges2shoes/train/train/6212_AB.jpg
# edges2shoes/train/train/6213_AB.jpg
# edges2shoes/train/train/6214_AB.jpg
# edges2shoes/train/train/6215_AB.jpg
# edges2shoes/train/train/6216_AB.jpg
# edges2shoes/train/train/6217_AB.jpg
# edges2shoes/train/train/6218_AB.jpg
# edges2shoes/train/train/6219_AB.jpg
# edges2shoes/train/train/621_AB.jpg
# edges2shoes/train/train/6220_AB.jpg
# edges2shoes/train/train/6221_AB.jpg
# edges2shoes/train/train/6222_AB.jpg
# edges2shoes/train/train/6223_AB.jpg
# edges2shoes/train/train/6224_AB.jpg
# edges2shoes/train/train/6225_AB.jpg
# edges2shoes/train/train/6226_AB.jpg
# edges2shoes/train/train/6227_AB.jpg
# edges2shoes/train/train/6228_AB.jpg
# edges2shoes/train/train/6229_AB.jpg
# edges2shoes/train/train/622_AB.jpg
# edges2shoes/train/train/6230_AB.jpg
# edges2shoes/train/train/6231_AB.jpg
# edges2shoes/train/train/6232_AB.jpg
# edges2shoes/train/train/6233_AB.jpg
# edges2shoes/train/train/6234_AB.jpg
# edges2shoes/train/train/6235_AB.jpg
# edges2shoes/train/train/6236_AB.jpg
# edges2shoes/train/train/6237_AB.jpg
# edges2shoes/train/train/6238_AB.jpg
# edges2shoes/train/train/6239_AB.jpg
# edges2shoes/train/train/623_AB.jpg
# edges2shoes/train/train/6240_AB.jpg
# edges2shoes/train/train/6241_AB.jpg
# edges2shoes/train/train/6242_AB.jpg
# edges2shoes/train/train/6243_AB.jpg
# edges2shoes/train/train/6244_AB.jpg
# edges2shoes/train/train/6245_AB.jpg
# edges2shoes/train/train/6246_AB.jpg
# edges2shoes/train/train/6247_AB.jpg
# edges2shoes/train/train/6248_AB.jpg
# edges2shoes/train/train/6249_AB.jpg
# edges2shoes/train/train/624_AB.jpg
# edges2shoes/train/train/6250_AB.jpg
# edges2shoes/train/train/6251_AB.jpg
# edges2shoes/train/train/6252_AB.jpg
# edges2shoes/train/train/6253_AB.jpg
# edges2shoes/train/train/6254_AB.jpg
# edges2shoes/train/train/6255_AB.jpg
# edges2shoes/train/train/6256_AB.jpg
# edges2shoes/train/train/6257_AB.jpg
# edges2shoes/train/train/6258_AB.jpg
# edges2shoes/train/train/6259_AB.jpg
# edges2shoes/train/train/625_AB.jpg
# edges2shoes/train/train/6260_AB.jpg
# edges2shoes/train/train/6261_AB.jpg
# edges2shoes/train/train/6262_AB.jpg
# edges2shoes/train/train/6263_AB.jpg
# edges2shoes/train/train/6264_AB.jpg
# edges2shoes/train/train/6265_AB.jpg
# edges2shoes/train/train/6266_AB.jpg
# edges2shoes/train/train/6267_AB.jpg
# edges2shoes/train/train/6268_AB.jpg
# edges2shoes/train/train/6269_AB.jpg
# edges2shoes/train/train/626_AB.jpg
# edges2shoes/train/train/6270_AB.jpg
# edges2shoes/train/train/6271_AB.jpg
# edges2shoes/train/train/6272_AB.jpg
# edges2shoes/train/train/6273_AB.jpg
# edges2shoes/train/train/6274_AB.jpg
# edges2shoes/train/train/6275_AB.jpg
# edges2shoes/train/train/6276_AB.jpg
# edges2shoes/train/train/6277_AB.jpg
# edges2shoes/train/train/6278_AB.jpg
# edges2shoes/train/train/6279_AB.jpg
# edges2shoes/train/train/627_AB.jpg
# edges2shoes/train/train/6280_AB.jpg
# edges2shoes/train/train/6281_AB.jpg
# edges2shoes/train/train/6282_AB.jpg
# edges2shoes/train/train/6283_AB.jpg
# edges2shoes/train/train/6284_AB.jpg
# edges2shoes/train/train/6285_AB.jpg
# edges2shoes/train/train/6286_AB.jpg
# edges2shoes/train/train/6287_AB.jpg
# edges2shoes/train/train/6288_AB.jpg
# edges2shoes/train/train/6289_AB.jpg
# edges2shoes/train/train/628_AB.jpg
# edges2shoes/train/train/6290_AB.jpg
# edges2shoes/train/train/6291_AB.jpg
# edges2shoes/train/train/6292_AB.jpg
# edges2shoes/train/train/6293_AB.jpg
# edges2shoes/train/train/6294_AB.jpg
# edges2shoes/train/train/6295_AB.jpg
# edges2shoes/train/train/6296_AB.jpg
# edges2shoes/train/train/6297_AB.jpg
# edges2shoes/train/train/6298_AB.jpg
# edges2shoes/train/train/6299_AB.jpg
# edges2shoes/train/train/629_AB.jpg
# edges2shoes/train/train/62_AB.jpg
# edges2shoes/train/train/6300_AB.jpg
# edges2shoes/train/train/6301_AB.jpg
# edges2shoes/train/train/6302_AB.jpg
# edges2shoes/train/train/6303_AB.jpg
# edges2shoes/train/train/6304_AB.jpg
# edges2shoes/train/train/6305_AB.jpg
# edges2shoes/train/train/6306_AB.jpg
# edges2shoes/train/train/6307_AB.jpg
# edges2shoes/train/train/6308_AB.jpg
# edges2shoes/train/train/6309_AB.jpg
# edges2shoes/train/train/630_AB.jpg
# edges2shoes/train/train/6310_AB.jpg
# edges2shoes/train/train/6311_AB.jpg
# edges2shoes/train/train/6312_AB.jpg
# edges2shoes/train/train/6313_AB.jpg
# edges2shoes/train/train/6314_AB.jpg
# edges2shoes/train/train/6315_AB.jpg
# edges2shoes/train/train/6316_AB.jpg
# edges2shoes/train/train/6317_AB.jpg
# edges2shoes/train/train/6318_AB.jpg
# edges2shoes/train/train/6319_AB.jpg
# edges2shoes/train/train/631_AB.jpg
# edges2shoes/train/train/6320_AB.jpg
# edges2shoes/train/train/6321_AB.jpg
# edges2shoes/train/train/6322_AB.jpg
# edges2shoes/train/train/6323_AB.jpg
# edges2shoes/train/train/6324_AB.jpg
# edges2shoes/train/train/6325_AB.jpg
# edges2shoes/train/train/6326_AB.jpg
# edges2shoes/train/train/6327_AB.jpg
# edges2shoes/train/train/6328_AB.jpg
# edges2shoes/train/train/6329_AB.jpg
# edges2shoes/train/train/632_AB.jpg
# edges2shoes/train/train/6330_AB.jpg
# edges2shoes/train/train/6331_AB.jpg
# edges2shoes/train/train/6332_AB.jpg
# edges2shoes/train/train/6333_AB.jpg
# edges2shoes/train/train/6334_AB.jpg
# edges2shoes/train/train/6335_AB.jpg
# edges2shoes/train/train/6336_AB.jpg
# edges2shoes/train/train/6337_AB.jpg
# edges2shoes/train/train/6338_AB.jpg
# edges2shoes/train/train/6339_AB.jpg
# edges2shoes/train/train/633_AB.jpg
# edges2shoes/train/train/6340_AB.jpg
# edges2shoes/train/train/6341_AB.jpg
# edges2shoes/train/train/6342_AB.jpg
# edges2shoes/train/train/6343_AB.jpg
# edges2shoes/train/train/6344_AB.jpg
# edges2shoes/train/train/6345_AB.jpg
# edges2shoes/train/train/6346_AB.jpg
# edges2shoes/train/train/6347_AB.jpg
# edges2shoes/train/train/6348_AB.jpg
# edges2shoes/train/train/6349_AB.jpg
# edges2shoes/train/train/634_AB.jpg
# edges2shoes/train/train/6350_AB.jpg
# edges2shoes/train/train/6351_AB.jpg
# edges2shoes/train/train/6352_AB.jpg
# edges2shoes/train/train/6353_AB.jpg
# edges2shoes/train/train/6354_AB.jpg
# edges2shoes/train/train/6355_AB.jpg
# edges2shoes/train/train/6356_AB.jpg
# edges2shoes/train/train/6357_AB.jpg
# edges2shoes/train/train/6358_AB.jpg
# edges2shoes/train/train/6359_AB.jpg
# edges2shoes/train/train/635_AB.jpg
# edges2shoes/train/train/6360_AB.jpg
# edges2shoes/train/train/6361_AB.jpg
# edges2shoes/train/train/6362_AB.jpg
# edges2shoes/train/train/6363_AB.jpg
# edges2shoes/train/train/6364_AB.jpg
# edges2shoes/train/train/6365_AB.jpg
# edges2shoes/train/train/6366_AB.jpg
# edges2shoes/train/train/6367_AB.jpg
# edges2shoes/train/train/6368_AB.jpg
# edges2shoes/train/train/6369_AB.jpg
# edges2shoes/train/train/636_AB.jpg
# edges2shoes/train/train/6370_AB.jpg
# edges2shoes/train/train/6371_AB.jpg
# edges2shoes/train/train/6372_AB.jpg
# edges2shoes/train/train/6373_AB.jpg
# edges2shoes/train/train/6374_AB.jpg
# edges2shoes/train/train/6375_AB.jpg
# edges2shoes/train/train/6376_AB.jpg
# edges2shoes/train/train/6377_AB.jpg
# edges2shoes/train/train/6378_AB.jpg
# edges2shoes/train/train/6379_AB.jpg
# edges2shoes/train/train/637_AB.jpg
# edges2shoes/train/train/6380_AB.jpg
# edges2shoes/train/train/6381_AB.jpg
# edges2shoes/train/train/6382_AB.jpg
# edges2shoes/train/train/6383_AB.jpg
# edges2shoes/train/train/6384_AB.jpg
# edges2shoes/train/train/6385_AB.jpg
# edges2shoes/train/train/6386_AB.jpg
# edges2shoes/train/train/6387_AB.jpg
# edges2shoes/train/train/6388_AB.jpg
# edges2shoes/train/train/6389_AB.jpg
# edges2shoes/train/train/638_AB.jpg
# edges2shoes/train/train/6390_AB.jpg
# edges2shoes/train/train/6391_AB.jpg
# edges2shoes/train/train/6392_AB.jpg
# edges2shoes/train/train/6393_AB.jpg
# edges2shoes/train/train/6394_AB.jpg
# edges2shoes/train/train/6395_AB.jpg
# edges2shoes/train/train/6396_AB.jpg
# edges2shoes/train/train/6397_AB.jpg
# edges2shoes/train/train/6398_AB.jpg
# edges2shoes/train/train/6399_AB.jpg
# edges2shoes/train/train/639_AB.jpg
# edges2shoes/train/train/63_AB.jpg
# edges2shoes/train/train/6400_AB.jpg
# edges2shoes/train/train/6401_AB.jpg
# edges2shoes/train/train/6402_AB.jpg
# edges2shoes/train/train/6403_AB.jpg
# edges2shoes/train/train/6404_AB.jpg
# edges2shoes/train/train/6405_AB.jpg
# edges2shoes/train/train/6406_AB.jpg
# edges2shoes/train/train/6407_AB.jpg
# edges2shoes/train/train/6408_AB.jpg
# edges2shoes/train/train/6409_AB.jpg
# edges2shoes/train/train/640_AB.jpg
# edges2shoes/train/train/6410_AB.jpg
# edges2shoes/train/train/6411_AB.jpg
# edges2shoes/train/train/6412_AB.jpg
# edges2shoes/train/train/6413_AB.jpg
# edges2shoes/train/train/6414_AB.jpg
# edges2shoes/train/train/6415_AB.jpg
# edges2shoes/train/train/6416_AB.jpg
# edges2shoes/train/train/6417_AB.jpg
# edges2shoes/train/train/6418_AB.jpg
# edges2shoes/train/train/6419_AB.jpg
# edges2shoes/train/train/641_AB.jpg
# edges2shoes/train/train/6420_AB.jpg
# edges2shoes/train/train/6421_AB.jpg
# edges2shoes/train/train/6422_AB.jpg
# edges2shoes/train/train/6423_AB.jpg
# edges2shoes/train/train/6424_AB.jpg
# edges2shoes/train/train/6425_AB.jpg
# edges2shoes/train/train/6426_AB.jpg
# edges2shoes/train/train/6427_AB.jpg
# edges2shoes/train/train/6428_AB.jpg
# edges2shoes/train/train/6429_AB.jpg
# edges2shoes/train/train/642_AB.jpg
# edges2shoes/train/train/6430_AB.jpg
# edges2shoes/train/train/6431_AB.jpg
# edges2shoes/train/train/6432_AB.jpg
# edges2shoes/train/train/6433_AB.jpg
# edges2shoes/train/train/6434_AB.jpg
# edges2shoes/train/train/6435_AB.jpg
# edges2shoes/train/train/6436_AB.jpg
# edges2shoes/train/train/6437_AB.jpg
# edges2shoes/train/train/6438_AB.jpg
# edges2shoes/train/train/6439_AB.jpg
# edges2shoes/train/train/643_AB.jpg
# edges2shoes/train/train/6440_AB.jpg
# edges2shoes/train/train/6441_AB.jpg
# edges2shoes/train/train/6442_AB.jpg
# edges2shoes/train/train/6443_AB.jpg
# edges2shoes/train/train/6444_AB.jpg
# edges2shoes/train/train/6445_AB.jpg
# edges2shoes/train/train/6446_AB.jpg
# edges2shoes/train/train/6447_AB.jpg
# edges2shoes/train/train/6448_AB.jpg
# edges2shoes/train/train/6449_AB.jpg
# edges2shoes/train/train/644_AB.jpg
# edges2shoes/train/train/6450_AB.jpg
# edges2shoes/train/train/6451_AB.jpg
# edges2shoes/train/train/6452_AB.jpg
# edges2shoes/train/train/6453_AB.jpg
# edges2shoes/train/train/6454_AB.jpg
# edges2shoes/train/train/6455_AB.jpg
# edges2shoes/train/train/6456_AB.jpg
# edges2shoes/train/train/6457_AB.jpg
# edges2shoes/train/train/6458_AB.jpg
# edges2shoes/train/train/6459_AB.jpg
# edges2shoes/train/train/645_AB.jpg
# edges2shoes/train/train/6460_AB.jpg
# edges2shoes/train/train/6461_AB.jpg
# edges2shoes/train/train/6462_AB.jpg
# edges2shoes/train/train/6463_AB.jpg
# edges2shoes/train/train/6464_AB.jpg
# edges2shoes/train/train/6465_AB.jpg
# edges2shoes/train/train/6466_AB.jpg
# edges2shoes/train/train/6467_AB.jpg
# edges2shoes/train/train/6468_AB.jpg
# edges2shoes/train/train/6469_AB.jpg
# edges2shoes/train/train/646_AB.jpg
# edges2shoes/train/train/6470_AB.jpg
# edges2shoes/train/train/6471_AB.jpg
# edges2shoes/train/train/6472_AB.jpg
# edges2shoes/train/train/6473_AB.jpg
# edges2shoes/train/train/6474_AB.jpg
# edges2shoes/train/train/6475_AB.jpg
# edges2shoes/train/train/6476_AB.jpg
# edges2shoes/train/train/6477_AB.jpg
# edges2shoes/train/train/6478_AB.jpg
# edges2shoes/train/train/6479_AB.jpg
# edges2shoes/train/train/647_AB.jpg
# edges2shoes/train/train/6480_AB.jpg
# edges2shoes/train/train/6481_AB.jpg
# edges2shoes/train/train/6482_AB.jpg
# edges2shoes/train/train/6483_AB.jpg
# edges2shoes/train/train/6484_AB.jpg
# edges2shoes/train/train/6485_AB.jpg
# edges2shoes/train/train/6486_AB.jpg
# edges2shoes/train/train/6487_AB.jpg
# edges2shoes/train/train/6488_AB.jpg
# edges2shoes/train/train/6489_AB.jpg
# edges2shoes/train/train/648_AB.jpg
# edges2shoes/train/train/6490_AB.jpg
# edges2shoes/train/train/6491_AB.jpg
# edges2shoes/train/train/6492_AB.jpg
# edges2shoes/train/train/6493_AB.jpg
# edges2shoes/train/train/6494_AB.jpg
# edges2shoes/train/train/6495_AB.jpg
# edges2shoes/train/train/6496_AB.jpg
# edges2shoes/train/train/6497_AB.jpg
# edges2shoes/train/train/6498_AB.jpg
# edges2shoes/train/train/6499_AB.jpg
# edges2shoes/train/train/649_AB.jpg
# edges2shoes/train/train/64_AB.jpg
# edges2shoes/train/train/6500_AB.jpg
# edges2shoes/train/train/6501_AB.jpg
# edges2shoes/train/train/6502_AB.jpg
# edges2shoes/train/train/6503_AB.jpg
# edges2shoes/train/train/6504_AB.jpg
# edges2shoes/train/train/6505_AB.jpg
# edges2shoes/train/train/6506_AB.jpg
# edges2shoes/train/train/6507_AB.jpg
# edges2shoes/train/train/6508_AB.jpg
# edges2shoes/train/train/6509_AB.jpg
# edges2shoes/train/train/650_AB.jpg
# edges2shoes/train/train/6510_AB.jpg
# edges2shoes/train/train/6511_AB.jpg
# edges2shoes/train/train/6512_AB.jpg
# edges2shoes/train/train/6513_AB.jpg
# edges2shoes/train/train/6514_AB.jpg
# edges2shoes/train/train/6515_AB.jpg
# edges2shoes/train/train/6516_AB.jpg
# edges2shoes/train/train/6517_AB.jpg
# edges2shoes/train/train/6518_AB.jpg
# edges2shoes/train/train/6519_AB.jpg
# edges2shoes/train/train/651_AB.jpg
# edges2shoes/train/train/6520_AB.jpg
# edges2shoes/train/train/6521_AB.jpg
# edges2shoes/train/train/6522_AB.jpg
# edges2shoes/train/train/6523_AB.jpg
# edges2shoes/train/train/6524_AB.jpg
# edges2shoes/train/train/6525_AB.jpg
# edges2shoes/train/train/6526_AB.jpg
# edges2shoes/train/train/6527_AB.jpg
# edges2shoes/train/train/6528_AB.jpg
# edges2shoes/train/train/6529_AB.jpg
# edges2shoes/train/train/652_AB.jpg
# edges2shoes/train/train/6530_AB.jpg
# edges2shoes/train/train/6531_AB.jpg
# edges2shoes/train/train/6532_AB.jpg
# edges2shoes/train/train/6533_AB.jpg
# edges2shoes/train/train/6534_AB.jpg
# edges2shoes/train/train/6535_AB.jpg
# edges2shoes/train/train/6536_AB.jpg
# edges2shoes/train/train/6537_AB.jpg
# edges2shoes/train/train/6538_AB.jpg
# edges2shoes/train/train/6539_AB.jpg
# edges2shoes/train/train/653_AB.jpg
# edges2shoes/train/train/6540_AB.jpg
# edges2shoes/train/train/6541_AB.jpg
# edges2shoes/train/train/6542_AB.jpg
# edges2shoes/train/train/6543_AB.jpg
# edges2shoes/train/train/6544_AB.jpg
# edges2shoes/train/train/6545_AB.jpg
# edges2shoes/train/train/6546_AB.jpg
# edges2shoes/train/train/6547_AB.jpg
# edges2shoes/train/train/6548_AB.jpg
# edges2shoes/train/train/6549_AB.jpg
# edges2shoes/train/train/654_AB.jpg
# edges2shoes/train/train/6550_AB.jpg
# edges2shoes/train/train/6551_AB.jpg
# edges2shoes/train/train/6552_AB.jpg
# edges2shoes/train/train/6553_AB.jpg
# edges2shoes/train/train/6554_AB.jpg
# edges2shoes/train/train/6555_AB.jpg
# edges2shoes/train/train/6556_AB.jpg
# edges2shoes/train/train/6557_AB.jpg
# edges2shoes/train/train/6558_AB.jpg
# edges2shoes/train/train/6559_AB.jpg
# edges2shoes/train/train/655_AB.jpg
# edges2shoes/train/train/6560_AB.jpg
# edges2shoes/train/train/6561_AB.jpg
# edges2shoes/train/train/6562_AB.jpg
# edges2shoes/train/train/6563_AB.jpg
# edges2shoes/train/train/6564_AB.jpg
# edges2shoes/train/train/6565_AB.jpg
# edges2shoes/train/train/6566_AB.jpg
# edges2shoes/train/train/6567_AB.jpg
# edges2shoes/train/train/6568_AB.jpg
# edges2shoes/train/train/6569_AB.jpg
# edges2shoes/train/train/656_AB.jpg
# edges2shoes/train/train/6570_AB.jpg
# edges2shoes/train/train/6571_AB.jpg
# edges2shoes/train/train/6572_AB.jpg
# edges2shoes/train/train/6573_AB.jpg
# edges2shoes/train/train/6574_AB.jpg
# edges2shoes/train/train/6575_AB.jpg
# edges2shoes/train/train/6576_AB.jpg
# edges2shoes/train/train/6577_AB.jpg
# edges2shoes/train/train/6578_AB.jpg
# edges2shoes/train/train/6579_AB.jpg
# edges2shoes/train/train/657_AB.jpg
# edges2shoes/train/train/6580_AB.jpg
# edges2shoes/train/train/6581_AB.jpg
# edges2shoes/train/train/6582_AB.jpg
# edges2shoes/train/train/6583_AB.jpg
# edges2shoes/train/train/6584_AB.jpg
# edges2shoes/train/train/6585_AB.jpg
# edges2shoes/train/train/6586_AB.jpg
# edges2shoes/train/train/6587_AB.jpg
# edges2shoes/train/train/6588_AB.jpg
# edges2shoes/train/train/6589_AB.jpg
# edges2shoes/train/train/658_AB.jpg
# edges2shoes/train/train/6590_AB.jpg
# edges2shoes/train/train/6591_AB.jpg
# edges2shoes/train/train/6592_AB.jpg
# edges2shoes/train/train/6593_AB.jpg
# edges2shoes/train/train/6594_AB.jpg
# edges2shoes/train/train/6595_AB.jpg
# edges2shoes/train/train/6596_AB.jpg
# edges2shoes/train/train/6597_AB.jpg
# edges2shoes/train/train/6598_AB.jpg
# edges2shoes/train/train/6599_AB.jpg
# edges2shoes/train/train/659_AB.jpg
# edges2shoes/train/train/65_AB.jpg
# edges2shoes/train/train/6600_AB.jpg
# edges2shoes/train/train/6601_AB.jpg
# edges2shoes/train/train/6602_AB.jpg
# edges2shoes/train/train/6603_AB.jpg
# edges2shoes/train/train/6604_AB.jpg
# edges2shoes/train/train/6605_AB.jpg
# edges2shoes/train/train/6606_AB.jpg
# edges2shoes/train/train/6607_AB.jpg
# edges2shoes/train/train/6608_AB.jpg
# edges2shoes/train/train/6609_AB.jpg
# edges2shoes/train/train/660_AB.jpg
# edges2shoes/train/train/6610_AB.jpg
# edges2shoes/train/train/6611_AB.jpg
# edges2shoes/train/train/6612_AB.jpg
# edges2shoes/train/train/6613_AB.jpg
# edges2shoes/train/train/6614_AB.jpg
# edges2shoes/train/train/6615_AB.jpg
# edges2shoes/train/train/6616_AB.jpg
# edges2shoes/train/train/6617_AB.jpg
# edges2shoes/train/train/6618_AB.jpg
# edges2shoes/train/train/6619_AB.jpg
# edges2shoes/train/train/661_AB.jpg
# edges2shoes/train/train/6620_AB.jpg
# edges2shoes/train/train/6621_AB.jpg
# edges2shoes/train/train/6622_AB.jpg
# edges2shoes/train/train/6623_AB.jpg
# edges2shoes/train/train/6624_AB.jpg
# edges2shoes/train/train/6625_AB.jpg
# edges2shoes/train/train/6626_AB.jpg
# edges2shoes/train/train/6627_AB.jpg
# edges2shoes/train/train/6628_AB.jpg
# edges2shoes/train/train/6629_AB.jpg
# edges2shoes/train/train/662_AB.jpg
# edges2shoes/train/train/6630_AB.jpg
# edges2shoes/train/train/6631_AB.jpg
# edges2shoes/train/train/6632_AB.jpg
# edges2shoes/train/train/6633_AB.jpg
# edges2shoes/train/train/6634_AB.jpg
# edges2shoes/train/train/6635_AB.jpg
# edges2shoes/train/train/6636_AB.jpg
# edges2shoes/train/train/6637_AB.jpg
# edges2shoes/train/train/6638_AB.jpg
# edges2shoes/train/train/6639_AB.jpg
# edges2shoes/train/train/663_AB.jpg
# edges2shoes/train/train/6640_AB.jpg
# edges2shoes/train/train/6641_AB.jpg
# edges2shoes/train/train/6642_AB.jpg
# edges2shoes/train/train/6643_AB.jpg
# edges2shoes/train/train/6644_AB.jpg
# edges2shoes/train/train/6645_AB.jpg
# edges2shoes/train/train/6646_AB.jpg
# edges2shoes/train/train/6647_AB.jpg
# edges2shoes/train/train/6648_AB.jpg
# edges2shoes/train/train/6649_AB.jpg
# edges2shoes/train/train/664_AB.jpg
# edges2shoes/train/train/6650_AB.jpg
# edges2shoes/train/train/6651_AB.jpg
# edges2shoes/train/train/6652_AB.jpg
# edges2shoes/train/train/6653_AB.jpg
# edges2shoes/train/train/6654_AB.jpg
# edges2shoes/train/train/6655_AB.jpg
# edges2shoes/train/train/6656_AB.jpg
# edges2shoes/train/train/6657_AB.jpg
# edges2shoes/train/train/6658_AB.jpg
# edges2shoes/train/train/6659_AB.jpg
# edges2shoes/train/train/665_AB.jpg
# edges2shoes/train/train/6660_AB.jpg
# edges2shoes/train/train/6661_AB.jpg
# edges2shoes/train/train/6662_AB.jpg
# edges2shoes/train/train/6663_AB.jpg
# edges2shoes/train/train/6664_AB.jpg
# edges2shoes/train/train/6665_AB.jpg
# edges2shoes/train/train/6666_AB.jpg
# edges2shoes/train/train/6667_AB.jpg
# edges2shoes/train/train/6668_AB.jpg
# edges2shoes/train/train/6669_AB.jpg
# edges2shoes/train/train/666_AB.jpg
# edges2shoes/train/train/6670_AB.jpg
# edges2shoes/train/train/6671_AB.jpg
# edges2shoes/train/train/6672_AB.jpg
# edges2shoes/train/train/6673_AB.jpg
# edges2shoes/train/train/6674_AB.jpg
# edges2shoes/train/train/6675_AB.jpg
# edges2shoes/train/train/6676_AB.jpg
# edges2shoes/train/train/6677_AB.jpg
# edges2shoes/train/train/6678_AB.jpg
# edges2shoes/train/train/6679_AB.jpg
# edges2shoes/train/train/667_AB.jpg
# edges2shoes/train/train/6680_AB.jpg
# edges2shoes/train/train/6681_AB.jpg
# edges2shoes/train/train/6682_AB.jpg
# edges2shoes/train/train/6683_AB.jpg
# edges2shoes/train/train/6684_AB.jpg
# edges2shoes/train/train/6685_AB.jpg
# edges2shoes/train/train/6686_AB.jpg
# edges2shoes/train/train/6687_AB.jpg
# edges2shoes/train/train/6688_AB.jpg
# edges2shoes/train/train/6689_AB.jpg
# edges2shoes/train/train/668_AB.jpg
# edges2shoes/train/train/6690_AB.jpg
# edges2shoes/train/train/6691_AB.jpg
# edges2shoes/train/train/6692_AB.jpg
# edges2shoes/train/train/6693_AB.jpg
# edges2shoes/train/train/6694_AB.jpg
# edges2shoes/train/train/6695_AB.jpg
# edges2shoes/train/train/6696_AB.jpg
# edges2shoes/train/train/6697_AB.jpg
# edges2shoes/train/train/6698_AB.jpg
# edges2shoes/train/train/6699_AB.jpg
# edges2shoes/train/train/669_AB.jpg
# edges2shoes/train/train/66_AB.jpg
# edges2shoes/train/train/6700_AB.jpg
# edges2shoes/train/train/6701_AB.jpg
# edges2shoes/train/train/6702_AB.jpg
# edges2shoes/train/train/6703_AB.jpg
# edges2shoes/train/train/6704_AB.jpg
# edges2shoes/train/train/6705_AB.jpg
# edges2shoes/train/train/6706_AB.jpg
# edges2shoes/train/train/6707_AB.jpg
# edges2shoes/train/train/6708_AB.jpg
# edges2shoes/train/train/6709_AB.jpg
# edges2shoes/train/train/670_AB.jpg
# edges2shoes/train/train/6710_AB.jpg
# edges2shoes/train/train/6711_AB.jpg
# edges2shoes/train/train/6712_AB.jpg
# edges2shoes/train/train/6713_AB.jpg
# edges2shoes/train/train/6714_AB.jpg
# edges2shoes/train/train/6715_AB.jpg
# edges2shoes/train/train/6716_AB.jpg
# edges2shoes/train/train/6717_AB.jpg
# edges2shoes/train/train/6718_AB.jpg
# edges2shoes/train/train/6719_AB.jpg
# edges2shoes/train/train/671_AB.jpg
# edges2shoes/train/train/6720_AB.jpg
# edges2shoes/train/train/6721_AB.jpg
# edges2shoes/train/train/6722_AB.jpg
# edges2shoes/train/train/6723_AB.jpg
# edges2shoes/train/train/6724_AB.jpg
# edges2shoes/train/train/6725_AB.jpg
# edges2shoes/train/train/6726_AB.jpg
# edges2shoes/train/train/6727_AB.jpg
# edges2shoes/train/train/6728_AB.jpg
# edges2shoes/train/train/6729_AB.jpg
# edges2shoes/train/train/672_AB.jpg
# edges2shoes/train/train/6730_AB.jpg
# edges2shoes/train/train/6731_AB.jpg
# edges2shoes/train/train/6732_AB.jpg
# edges2shoes/train/train/6733_AB.jpg
# edges2shoes/train/train/6734_AB.jpg
# edges2shoes/train/train/6735_AB.jpg
# edges2shoes/train/train/6736_AB.jpg
# edges2shoes/train/train/6737_AB.jpg
# edges2shoes/train/train/6738_AB.jpg
# edges2shoes/train/train/6739_AB.jpg
# edges2shoes/train/train/673_AB.jpg
# edges2shoes/train/train/6740_AB.jpg
# edges2shoes/train/train/6741_AB.jpg
# edges2shoes/train/train/6742_AB.jpg
# edges2shoes/train/train/6743_AB.jpg
# edges2shoes/train/train/6744_AB.jpg
# edges2shoes/train/train/6745_AB.jpg
# edges2shoes/train/train/6746_AB.jpg
# edges2shoes/train/train/6747_AB.jpg
# edges2shoes/train/train/6748_AB.jpg
# edges2shoes/train/train/6749_AB.jpg
# edges2shoes/train/train/674_AB.jpg
# edges2shoes/train/train/6750_AB.jpg
# edges2shoes/train/train/6751_AB.jpg
# edges2shoes/train/train/6752_AB.jpg
# edges2shoes/train/train/6753_AB.jpg
# edges2shoes/train/train/6754_AB.jpg
# edges2shoes/train/train/6755_AB.jpg
# edges2shoes/train/train/6756_AB.jpg
# edges2shoes/train/train/6757_AB.jpg
# edges2shoes/train/train/6758_AB.jpg
# edges2shoes/train/train/6759_AB.jpg
# edges2shoes/train/train/675_AB.jpg
# edges2shoes/train/train/6760_AB.jpg
# edges2shoes/train/train/6761_AB.jpg
# edges2shoes/train/train/6762_AB.jpg
# edges2shoes/train/train/6763_AB.jpg
# edges2shoes/train/train/6764_AB.jpg
# edges2shoes/train/train/6765_AB.jpg
# edges2shoes/train/train/6766_AB.jpg
# edges2shoes/train/train/6767_AB.jpg
# edges2shoes/train/train/6768_AB.jpg
# edges2shoes/train/train/6769_AB.jpg
# edges2shoes/train/train/676_AB.jpg
# edges2shoes/train/train/6770_AB.jpg
# edges2shoes/train/train/6771_AB.jpg
# edges2shoes/train/train/6772_AB.jpg
# edges2shoes/train/train/6773_AB.jpg
# edges2shoes/train/train/6774_AB.jpg
# edges2shoes/train/train/6775_AB.jpg
# edges2shoes/train/train/6776_AB.jpg
# edges2shoes/train/train/6777_AB.jpg
# edges2shoes/train/train/6778_AB.jpg
# edges2shoes/train/train/6779_AB.jpg
# edges2shoes/train/train/677_AB.jpg
# edges2shoes/train/train/6780_AB.jpg
# edges2shoes/train/train/6781_AB.jpg
# edges2shoes/train/train/6782_AB.jpg
# edges2shoes/train/train/6783_AB.jpg
# edges2shoes/train/train/6784_AB.jpg
# edges2shoes/train/train/6785_AB.jpg
# edges2shoes/train/train/6786_AB.jpg
# edges2shoes/train/train/6787_AB.jpg
# edges2shoes/train/train/6788_AB.jpg
# edges2shoes/train/train/6789_AB.jpg
# edges2shoes/train/train/678_AB.jpg
# edges2shoes/train/train/6790_AB.jpg
# edges2shoes/train/train/6791_AB.jpg
# edges2shoes/train/train/6792_AB.jpg
# edges2shoes/train/train/6793_AB.jpg
# edges2shoes/train/train/6794_AB.jpg
# edges2shoes/train/train/6795_AB.jpg
# edges2shoes/train/train/6796_AB.jpg
# edges2shoes/train/train/6797_AB.jpg
# edges2shoes/train/train/6798_AB.jpg
# edges2shoes/train/train/6799_AB.jpg
# edges2shoes/train/train/679_AB.jpg
# edges2shoes/train/train/67_AB.jpg
# edges2shoes/train/train/6800_AB.jpg
# edges2shoes/train/train/6801_AB.jpg
# edges2shoes/train/train/6802_AB.jpg
# edges2shoes/train/train/6803_AB.jpg
# edges2shoes/train/train/6804_AB.jpg
# edges2shoes/train/train/6805_AB.jpg
# edges2shoes/train/train/6806_AB.jpg
# edges2shoes/train/train/6807_AB.jpg
# edges2shoes/train/train/6808_AB.jpg
# edges2shoes/train/train/6809_AB.jpg
# edges2shoes/train/train/680_AB.jpg
# edges2shoes/train/train/6810_AB.jpg
# edges2shoes/train/train/6811_AB.jpg
# edges2shoes/train/train/6812_AB.jpg
# edges2shoes/train/train/6813_AB.jpg
# edges2shoes/train/train/6814_AB.jpg
# edges2shoes/train/train/6815_AB.jpg
# edges2shoes/train/train/6816_AB.jpg
# edges2shoes/train/train/6817_AB.jpg
# edges2shoes/train/train/6818_AB.jpg
# edges2shoes/train/train/6819_AB.jpg
# edges2shoes/train/train/681_AB.jpg
# edges2shoes/train/train/6820_AB.jpg
# edges2shoes/train/train/6821_AB.jpg
# edges2shoes/train/train/6822_AB.jpg
# edges2shoes/train/train/6823_AB.jpg
# edges2shoes/train/train/6824_AB.jpg
# edges2shoes/train/train/6825_AB.jpg
# edges2shoes/train/train/6826_AB.jpg
# edges2shoes/train/train/6827_AB.jpg
# edges2shoes/train/train/6828_AB.jpg
# edges2shoes/train/train/6829_AB.jpg
# edges2shoes/train/train/682_AB.jpg
# edges2shoes/train/train/6830_AB.jpg
# edges2shoes/train/train/6831_AB.jpg
# edges2shoes/train/train/6832_AB.jpg
# edges2shoes/train/train/6833_AB.jpg
# edges2shoes/train/train/6834_AB.jpg
# edges2shoes/train/train/6835_AB.jpg
# edges2shoes/train/train/6836_AB.jpg
# edges2shoes/train/train/6837_AB.jpg
# edges2shoes/train/train/6838_AB.jpg
# edges2shoes/train/train/6839_AB.jpg
# edges2shoes/train/train/683_AB.jpg
# edges2shoes/train/train/6840_AB.jpg
# edges2shoes/train/train/6841_AB.jpg
# edges2shoes/train/train/6842_AB.jpg
# edges2shoes/train/train/6843_AB.jpg
# edges2shoes/train/train/6844_AB.jpg
# edges2shoes/train/train/6845_AB.jpg
# edges2shoes/train/train/6846_AB.jpg
# edges2shoes/train/train/6847_AB.jpg
# edges2shoes/train/train/6848_AB.jpg
# edges2shoes/train/train/6849_AB.jpg
# edges2shoes/train/train/684_AB.jpg
# edges2shoes/train/train/6850_AB.jpg
# edges2shoes/train/train/6851_AB.jpg
# edges2shoes/train/train/6852_AB.jpg
# edges2shoes/train/train/6853_AB.jpg
# edges2shoes/train/train/6854_AB.jpg
# edges2shoes/train/train/6855_AB.jpg
# edges2shoes/train/train/6856_AB.jpg
# edges2shoes/train/train/6857_AB.jpg
# edges2shoes/train/train/6858_AB.jpg
# edges2shoes/train/train/6859_AB.jpg
# edges2shoes/train/train/685_AB.jpg
# edges2shoes/train/train/6860_AB.jpg
# edges2shoes/train/train/6861_AB.jpg
# edges2shoes/train/train/6862_AB.jpg
# edges2shoes/train/train/6863_AB.jpg
# edges2shoes/train/train/6864_AB.jpg
# edges2shoes/train/train/6865_AB.jpg
# edges2shoes/train/train/6866_AB.jpg
# edges2shoes/train/train/6867_AB.jpg
# edges2shoes/train/train/6868_AB.jpg
# edges2shoes/train/train/6869_AB.jpg
# edges2shoes/train/train/686_AB.jpg
# edges2shoes/train/train/6870_AB.jpg
# edges2shoes/train/train/6871_AB.jpg
# edges2shoes/train/train/6872_AB.jpg
# edges2shoes/train/train/6873_AB.jpg
# edges2shoes/train/train/6874_AB.jpg
# edges2shoes/train/train/6875_AB.jpg
# edges2shoes/train/train/6876_AB.jpg
# edges2shoes/train/train/6877_AB.jpg
# edges2shoes/train/train/6878_AB.jpg
# edges2shoes/train/train/6879_AB.jpg
# edges2shoes/train/train/687_AB.jpg
# edges2shoes/train/train/6880_AB.jpg
# edges2shoes/train/train/6881_AB.jpg
# edges2shoes/train/train/6882_AB.jpg
# edges2shoes/train/train/6883_AB.jpg
# ...
# edges2shoes/train/train/9753_AB.jpg
# edges2shoes/train/train/9754_AB.jpg
# edges2shoes/train/train/9755_AB.jpg
# edges2shoes/train/train/9756_AB.jpg
# edges2shoes/train/train/9757_AB.jpg
# edges2shoes/train/train/9758_AB.jpg
# edges2shoes/train/train/9759_AB.jpg
# edges2shoes/train/train/975_AB.jpg
# edges2shoes/train/train/9760_AB.jpg
# edges2shoes/train/train/9761_AB.jpg
# edges2shoes/train/train/9762_AB.jpg
# edges2shoes/train/train/9763_AB.jpg
# edges2shoes/train/train/9764_AB.jpg
# edges2shoes/train/train/9765_AB.jpg
# edges2shoes/train/train/9766_AB.jpg
# edges2shoes/train/train/9767_AB.jpg
# edges2shoes/train/train/9768_AB.jpg
# edges2shoes/train/train/9769_AB.jpg
# edges2shoes/train/train/976_AB.jpg
# edges2shoes/train/train/9770_AB.jpg
# edges2shoes/train/train/9771_AB.jpg
# edges2shoes/train/train/9772_AB.jpg
# edges2shoes/train/train/9773_AB.jpg
# edges2shoes/train/train/9774_AB.jpg
# edges2shoes/train/train/9775_AB.jpg
# edges2shoes/train/train/9776_AB.jpg
# edges2shoes/train/train/9777_AB.jpg
# edges2shoes/train/train/9778_AB.jpg
# edges2shoes/train/train/9779_AB.jpg
# edges2shoes/train/train/977_AB.jpg
# edges2shoes/train/train/9780_AB.jpg
# edges2shoes/train/train/9781_AB.jpg
# edges2shoes/train/train/9782_AB.jpg
# edges2shoes/train/train/9783_AB.jpg
# edges2shoes/train/train/9784_AB.jpg
# edges2shoes/train/train/9785_AB.jpg
# edges2shoes/train/train/9786_AB.jpg
# edges2shoes/train/train/9787_AB.jpg
# edges2shoes/train/train/9788_AB.jpg
# edges2shoes/train/train/9789_AB.jpg
# edges2shoes/train/train/978_AB.jpg
# edges2shoes/train/train/9790_AB.jpg
# edges2shoes/train/train/9791_AB.jpg
# edges2shoes/train/train/9792_AB.jpg
# edges2shoes/train/train/9793_AB.jpg
# edges2shoes/train/train/9794_AB.jpg
# edges2shoes/train/train/9795_AB.jpg
# edges2shoes/train/train/9796_AB.jpg
# edges2shoes/train/train/9797_AB.jpg
# edges2shoes/train/train/9798_AB.jpg
# edges2shoes/train/train/9799_AB.jpg
# edges2shoes/train/train/979_AB.jpg
# edges2shoes/train/train/97_AB.jpg
# edges2shoes/train/train/9800_AB.jpg
# edges2shoes/train/train/9801_AB.jpg
# edges2shoes/train/train/9802_AB.jpg
# edges2shoes/train/train/9803_AB.jpg
# edges2shoes/train/train/9804_AB.jpg
# edges2shoes/train/train/9805_AB.jpg
# edges2shoes/train/train/9806_AB.jpg
# edges2shoes/train/train/9807_AB.jpg
# edges2shoes/train/train/9808_AB.jpg
# edges2shoes/train/train/9809_AB.jpg
# edges2shoes/train/train/980_AB.jpg
# edges2shoes/train/train/9810_AB.jpg
# edges2shoes/train/train/9811_AB.jpg
# edges2shoes/train/train/9812_AB.jpg
# edges2shoes/train/train/9813_AB.jpg
# edges2shoes/train/train/9814_AB.jpg
# edges2shoes/train/train/9815_AB.jpg
# edges2shoes/train/train/9816_AB.jpg
# edges2shoes/train/train/9817_AB.jpg
# edges2shoes/train/train/9818_AB.jpg
# edges2shoes/train/train/9819_AB.jpg
# edges2shoes/train/train/981_AB.jpg
# edges2shoes/train/train/9820_AB.jpg
# edges2shoes/train/train/9821_AB.jpg
# edges2shoes/train/train/9822_AB.jpg
# edges2shoes/train/train/9823_AB.jpg
# edges2shoes/train/train/9824_AB.jpg
# edges2shoes/train/train/9825_AB.jpg
# edges2shoes/train/train/9826_AB.jpg
# edges2shoes/train/train/9827_AB.jpg
# edges2shoes/train/train/9828_AB.jpg
# edges2shoes/train/train/9829_AB.jpg
# edges2shoes/train/train/982_AB.jpg
# edges2shoes/train/train/9830_AB.jpg
# edges2shoes/train/train/9831_AB.jpg
# edges2shoes/train/train/9832_AB.jpg
# edges2shoes/train/train/9833_AB.jpg
# edges2shoes/train/train/9834_AB.jpg
# edges2shoes/train/train/9835_AB.jpg
# edges2shoes/train/train/9836_AB.jpg
# edges2shoes/train/train/9837_AB.jpg
# edges2shoes/train/train/9838_AB.jpg
# edges2shoes/train/train/9839_AB.jpg
# edges2shoes/train/train/983_AB.jpg
# edges2shoes/train/train/9840_AB.jpg
# edges2shoes/train/train/9841_AB.jpg
# edges2shoes/train/train/9842_AB.jpg
# edges2shoes/train/train/9843_AB.jpg
# edges2shoes/train/train/9844_AB.jpg
# edges2shoes/train/train/9845_AB.jpg
# edges2shoes/train/train/9846_AB.jpg
# edges2shoes/train/train/9847_AB.jpg
# edges2shoes/train/train/9848_AB.jpg
# edges2shoes/train/train/9849_AB.jpg
# edges2shoes/train/train/984_AB.jpg
# edges2shoes/train/train/9850_AB.jpg
# edges2shoes/train/train/9851_AB.jpg
# edges2shoes/train/train/9852_AB.jpg
# edges2shoes/train/train/9853_AB.jpg
# edges2shoes/train/train/9854_AB.jpg
# edges2shoes/train/train/9855_AB.jpg
# edges2shoes/train/train/9856_AB.jpg
# edges2shoes/train/train/9857_AB.jpg
# edges2shoes/train/train/9858_AB.jpg
# edges2shoes/train/train/9859_AB.jpg
# edges2shoes/train/train/985_AB.jpg
# edges2shoes/train/train/9860_AB.jpg
# edges2shoes/train/train/9861_AB.jpg
# edges2shoes/train/train/9862_AB.jpg
# edges2shoes/train/train/9863_AB.jpg
# edges2shoes/train/train/9864_AB.jpg
# edges2shoes/train/train/9865_AB.jpg
# edges2shoes/train/train/9866_AB.jpg
# edges2shoes/train/train/9867_AB.jpg
# edges2shoes/train/train/9868_AB.jpg
# edges2shoes/train/train/9869_AB.jpg
# edges2shoes/train/train/986_AB.jpg
# edges2shoes/train/train/9870_AB.jpg
# edges2shoes/train/train/9871_AB.jpg
# edges2shoes/train/train/9872_AB.jpg
# edges2shoes/train/train/9873_AB.jpg
# edges2shoes/train/train/9874_AB.jpg
# edges2shoes/train/train/9875_AB.jpg
# edges2shoes/train/train/9876_AB.jpg
# edges2shoes/train/train/9877_AB.jpg
# edges2shoes/train/train/9878_AB.jpg
# edges2shoes/train/train/9879_AB.jpg
# edges2shoes/train/train/987_AB.jpg
# edges2shoes/train/train/9880_AB.jpg
# edges2shoes/train/train/9881_AB.jpg
# edges2shoes/train/train/9882_AB.jpg
# edges2shoes/train/train/9883_AB.jpg
# edges2shoes/train/train/9884_AB.jpg
# edges2shoes/train/train/9885_AB.jpg
# edges2shoes/train/train/9886_AB.jpg
# edges2shoes/train/train/9887_AB.jpg
# edges2shoes/train/train/9888_AB.jpg
# edges2shoes/train/train/9889_AB.jpg
# edges2shoes/train/train/988_AB.jpg
# edges2shoes/train/train/9890_AB.jpg
# edges2shoes/train/train/9891_AB.jpg
# edges2shoes/train/train/9892_AB.jpg
# edges2shoes/train/train/9893_AB.jpg
# edges2shoes/train/train/9894_AB.jpg
# edges2shoes/train/train/9895_AB.jpg
# edges2shoes/train/train/9896_AB.jpg
# edges2shoes/train/train/9897_AB.jpg
# edges2shoes/train/train/9898_AB.jpg
# edges2shoes/train/train/9899_AB.jpg
# edges2shoes/train/train/989_AB.jpg
# edges2shoes/train/train/98_AB.jpg
# edges2shoes/train/train/9900_AB.jpg
# edges2shoes/train/train/9901_AB.jpg
# edges2shoes/train/train/9902_AB.jpg
# edges2shoes/train/train/9903_AB.jpg
# edges2shoes/train/train/9904_AB.jpg
# edges2shoes/train/train/9905_AB.jpg
# edges2shoes/train/train/9906_AB.jpg
# edges2shoes/train/train/9907_AB.jpg
# edges2shoes/train/train/9908_AB.jpg
# edges2shoes/train/train/9909_AB.jpg
# edges2shoes/train/train/990_AB.jpg
# edges2shoes/train/train/9910_AB.jpg
# edges2shoes/train/train/9911_AB.jpg
# edges2shoes/train/train/9912_AB.jpg
# edges2shoes/train/train/9913_AB.jpg
# edges2shoes/train/train/9914_AB.jpg
# edges2shoes/train/train/9915_AB.jpg
# edges2shoes/train/train/9916_AB.jpg
# edges2shoes/train/train/9917_AB.jpg
# edges2shoes/train/train/9918_AB.jpg
# edges2shoes/train/train/9919_AB.jpg
# edges2shoes/train/train/991_AB.jpg
# edges2shoes/train/train/9920_AB.jpg
# edges2shoes/train/train/9921_AB.jpg
# edges2shoes/train/train/9922_AB.jpg
# edges2shoes/train/train/9923_AB.jpg
# edges2shoes/train/train/9924_AB.jpg
# edges2shoes/train/train/9925_AB.jpg
# edges2shoes/train/train/9926_AB.jpg
# edges2shoes/train/train/9927_AB.jpg
# edges2shoes/train/train/9928_AB.jpg
# edges2shoes/train/train/9929_AB.jpg
# edges2shoes/train/train/992_AB.jpg
# edges2shoes/train/train/9930_AB.jpg
# edges2shoes/train/train/9931_AB.jpg
# edges2shoes/train/train/9932_AB.jpg
# edges2shoes/train/train/9933_AB.jpg
# edges2shoes/train/train/9934_AB.jpg
# edges2shoes/train/train/9935_AB.jpg
# edges2shoes/train/train/9936_AB.jpg
# edges2shoes/train/train/9937_AB.jpg
# edges2shoes/train/train/9938_AB.jpg
# edges2shoes/train/train/9939_AB.jpg
# edges2shoes/train/train/993_AB.jpg
# edges2shoes/train/train/9940_AB.jpg
# edges2shoes/train/train/9941_AB.jpg
# edges2shoes/train/train/9942_AB.jpg
# edges2shoes/train/train/9943_AB.jpg
# edges2shoes/train/train/9944_AB.jpg
# edges2shoes/train/train/9945_AB.jpg
# edges2shoes/train/train/9946_AB.jpg
# edges2shoes/train/train/9947_AB.jpg
# edges2shoes/train/train/9948_AB.jpg
# edges2shoes/train/train/9949_AB.jpg
# edges2shoes/train/train/994_AB.jpg
# edges2shoes/train/train/9950_AB.jpg
# edges2shoes/train/train/9951_AB.jpg
# edges2shoes/train/train/9952_AB.jpg
# edges2shoes/train/train/9953_AB.jpg
# edges2shoes/train/train/9954_AB.jpg
# edges2shoes/train/train/9955_AB.jpg
# edges2shoes/train/train/9956_AB.jpg
# edges2shoes/train/train/9957_AB.jpg
# edges2shoes/train/train/9958_AB.jpg
# edges2shoes/train/train/9959_AB.jpg
# edges2shoes/train/train/995_AB.jpg
# edges2shoes/train/train/9960_AB.jpg
# edges2shoes/train/train/9961_AB.jpg
# edges2shoes/train/train/9962_AB.jpg
# edges2shoes/train/train/9963_AB.jpg
# edges2shoes/train/train/9964_AB.jpg
# edges2shoes/train/train/9965_AB.jpg
# edges2shoes/train/train/9966_AB.jpg
# edges2shoes/train/train/9967_AB.jpg
# edges2shoes/train/train/9968_AB.jpg
# edges2shoes/train/train/9969_AB.jpg
# edges2shoes/train/train/996_AB.jpg
# edges2shoes/train/train/9970_AB.jpg
# edges2shoes/train/train/9971_AB.jpg
# edges2shoes/train/train/9972_AB.jpg
# edges2shoes/train/train/9973_AB.jpg
# edges2shoes/train/train/9974_AB.jpg
# edges2shoes/train/train/9975_AB.jpg
# edges2shoes/train/train/9976_AB.jpg
# edges2shoes/train/train/9977_AB.jpg
# edges2shoes/train/train/9978_AB.jpg
# edges2shoes/train/train/9979_AB.jpg
# edges2shoes/train/train/997_AB.jpg
# edges2shoes/train/train/9980_AB.jpg
# edges2shoes/train/train/9981_AB.jpg
# edges2shoes/val/val/98_AB.jpg
# edges2shoes/val/val/99_AB.jpg
# edges2shoes/val/val/9_AB.jpg

# %% [markdown]
# ## 1. Implementation for CycleGAN
# >
# >
# > <img src="https://drive.google.com/uc?id=1F12jzfLYThE_Ci-zJ7T761-tq1fGlv3H" alt="no_image" style="width: 800px;"/><br>
# >
# > * Cycle GAN leverages a cycle consistency in image-to-image translation
# > * Unlike a conditional GAN, the cycle GAN considers <U>unpaired training data</U>
# >
# > **1. Dataset**
# >
# >   * MNIST dataset
# >   * SVHN dataset
# >   * Note that the MNIST data is gray, where the number of the channel is 1
# >
# > **2. Network architecture**
# >
# >   * **Overall architecture**
# >
# > <img src="https://drive.google.com/uc?id=1rJyEJOmSeboOsKyFPPoanvkaaiOpXNNA" alt="no_image" style="width: 600px;"/><br>
# >
# >   * **Generative model G**
# >     * Xavier initialization (Glorot & Bengio [3])
# >       * It makes sure the weights to keep the propagation in a reasonable range through many layers
# >       * $V(W)= {2 \over n_{in}+n_{out}}$
# >       * Use <code>nn.init.xavier_uniform_</code> for the Xavier initialization
# >
# >     * The generative model has three components:
# >       1. Encoder:
# >         * Convolutional network for feature extracting
# >         * 2 convolutional layers and 2 LeakyReLU activations
# >         * The output channel sizes are 64, 128 respectively<br>
# >         * The kernel size of the convolutional layers are 7 and 3, respectively<br>
# >            (You can use different sizes whatever you want, but we recommend those sizes)
# >         * All the strides are 2
# >         * Use batch normalization except for the first layer
# >
# >       2. Transformer:
# >         * Learn how it would like to transform the feature vector of and image from A to B. <br>
# >         * Use the resnet blok which contains the skip-connetction between the input and output for transformation<br>
# >            (Please refer to <U>He et al.</U>[3])
# >         * 3 resnet block layers and each of layer is followed by LeakyReLU activation
# >         * All the output channel sizes are 128
# >         * All the kernel sizes and strides are 3 and 1, respectively
# >
# >       3. Decoder:
# >         * Upconvolutional network for reconstructing an image
# >         * 2 upconvolutional layers, one LeakyReLU activations, and one Tanh activation which is for the last layer
# >         * The output channel sizes are 128, 64, and 3, respectively for the SVHN data, and 128, 64, and 1, respectively for the MNIST data <br>
# >         * All the kernel sizes and strides are 4 and 2, respectively
# >         * Use batch normalization except for the last layers
# >
# >
# >
# > <img src="https://drive.google.com/uc?id=1bsBowFWGDacoQBUZk-Lzh412IlEUZfmO" alt="no_image" style="width: 800px;"/><br>
# >
# >
# >   * **Discriminative model D**
# >     * Xavier Initialization
# >     * It contains 4 convolutional layers, 3 LeakyReLU activations, and one Sigmoid activation which is for the last layer
# >     * The output channel sizes are 64, 128, 256, and 1, respectively
# >     * All the kernel sizes are 4 except for the last kernel size which is 1
# >     * The strides from the first two layers are 2 and the rest of them are 1
# >     * Use batch normalization([4]) except for the first and last layers
# >
# >
# >
# > <img src="https://drive.google.com/uc?id=1BWt04F4K7BSaAANlXvLG_4Jg1Eyk8zsT" alt="no_image" style="width: 600px;"/><br>
# >
# >
# > **3. Loss function**<br>
# > (In the paper, the authors use the L2 loss for the GAN loss, but the binary cross entropy loss also works well)
# >  * **Discriminative model $D_X$ and $D_Y$**
# >    * The loss for $D_Y$ is followed as<br>
# >      * Binary cross entropy loss for the real data
# >      * Binary cross entropy loss for the fake data <br>
# >
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{real}log(D_Y(y_i))+(1-l_i^{real})log(1-D_Y(y_i)) $ <br>
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{fake}log(D_Y(G_Y(x_i)))+(1-l_i^{fake})log(1-D_Y(G_Y(x_i)))$ <br>
# >
# >  *
# >    * The loss for $D_Y$ is followed as<br>
# >      * Binary cross entropy loss for the real data
# >      * Binary cross entropy loss for the fake data <br>
# >
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{real}log(D_X(x_i))+(1-l_i^{real})log(1-D_X(x_i)) $ <br>
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{fake}log(D_X(G_X(y_i)))+(1-l_i^{fake})log(1-D_X(G_X(y_i)))$ <br>
# >
# >    ($l_i^{real}=1, l_i^{fake}=0$) <br>
# >    ($G_Y$ is the generator where $x_i$ translate to $y_i$ and vice versa)
# >
# >
# >  * **Generative model $G_X$ and $G_Y$**<br>
# >
# >      * Binary cross entropy loss for the real data (It is actually fake)
# >
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{real}log(D_X(G_X(y_i)))+(1-l_i^{real})log(1-D_X(G_X(y_i))) $ <br>
# >    $-{1 \over N} \sum^{N}_{i=1} l_i^{real}log(D_Y(G_Y(x_i)))+(1-l_i^{real})log(1-D_Y(G_Y(x_i))) $ <br>
# >
# >    ($l_i^{real}=1$)
# >
# >      * The cycle loss for measuring difference between $x_i$ and $G_Y(G_X(x_i))$ and vice versa
# >
# >    $-{1 \over N} \sum^{N}_{i=1} \lvert\lvert G_Y(G_X(y_i))-y_i \rvert\rvert_1$ <br>
# >    $-{1 \over N} \sum^{N}_{i=1} \lvert\lvert G_X(G_Y(x_i))-x_i \rvert\rvert_1$

# %% [markdown]
# ## 2. Cycle GAN with Pytorch

# %%
import os
import os.path as osp
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import time

# %matplotlib inline

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Parameter Setting
# * You can adjust the parameters to yourself

# %%
print('STEP 0: PARAMETER SETTING')

# Data root directory
train_X_root = 'datasets/lab7/mnist/'
train_Y_root = 'datasets/lab7/svhn/'

# Weight save directory
vis_num = 2
save_dir = 'cyclegan'
if not osp.exists(save_dir):
    os.makedirs(save_dir)

# Batch size during training
bs = 64

# Size of image
img_height = 32
img_width = 32
img_size = 32
img_channel = 3

# Channels of generator feature
gfc = 64

# Channels of discriminator feature
dfc = 64

# Number of training epochs
num_epochs = 5

# Learning rate for optimizing
lr = 0.0002

# Beta1 hyperparameter for Adam optimizers
beta1 = 0.5

# Real or Fake label
real_label = 1
fake_label = 0
# Out:
# STEP 0: PARAMETER SETTING

# %%
print('STEP 1: LOADING DATASET')

transform_1ch = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))])

transform_3ch = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


train_X_set = dset.MNIST(root=train_X_root,
                         train=True,
                         transform=transform_1ch,
                         download=True)
train_Y_set = dset.SVHN(root=train_Y_root,
                        split='train',
                        transform=transform_3ch,
                        download=True)
test_X_set = dset.MNIST(root=train_X_root,
                         train=False,
                         transform=transform_1ch,
                         download=True)
test_Y_set = dset.SVHN(root=train_Y_root,
                        split='test',
                        transform=transform_3ch,
                        download=True)
# Out:
# STEP 1: LOADING DATASET

# %%
print('STEP 2: MAKING DATASET ITERABLE')

train_X_loader = torch.utils.data.DataLoader(train_X_set,
                                             batch_size=bs,
                                             shuffle=True,
                                             drop_last=True)

train_Y_loader = torch.utils.data.DataLoader(train_Y_set,
                                             batch_size=bs,
                                             shuffle=True,
                                             drop_last=True)

test_X_loader = torch.utils.data.DataLoader(test_X_set,
                                             batch_size=bs,
                                             shuffle=False,
                                             drop_last=True)

test_Y_loader = torch.utils.data.DataLoader(test_Y_set,
                                             batch_size=bs,
                                             shuffle=False,
                                             drop_last=True)
# Out:
# STEP 2: MAKING DATASET ITERABLE

# %% [markdown]
# ### Visualize a few images

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
data_loader_X_sample = torch.utils.data.DataLoader(train_X_set,
                                                 batch_size=4,
                                                 shuffle=True)
data_loader_Y_sample = torch.utils.data.DataLoader(train_Y_set,
                                                 batch_size=4,
                                                 shuffle=True)

# Get a batch of training data
X = next(iter(data_loader_X_sample))
Y = next(iter(data_loader_Y_sample))

# Make a grid from batch
out_X = torchvision.utils.make_grid(X[0])
out_Y = torchvision.utils.make_grid(Y[0])

imshow(out_X)
imshow(out_Y)

# %% [markdown]
# ### Utils
# * Use the below code for the convolution or the upconvolution

# %% [markdown]
# ### *References*
# [1] Zhu et al., "Unpaired Image-to-Image Translation using Cycle-Consistent Adversarial Networks", *ICCV*, 2017. <br>
# [2] https://hardikbansal.github.io/CycleGANBlog/ <br>
# [3] Glorot & Bengio, "Understanding the difficulty of training deep feedforward neural networks", *AISTATS* 2010. <br>
# [4] Ioffe & Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift", *ICML* 2015.

# %%
def conv2d(params_list, batch_norm = True):
    channel_in, channel_out, kernel_size, stride, padding, activation = params_list
    layers = []
    if batch_norm:
        layers += [nn.Conv2d(channel_in, channel_out, kernel_size, stride, padding, bias=False),
                   nn.BatchNorm2d(channel_out)]
        nn.init.xavier_uniform_(layers[0].weight)
    else:
        layers += [nn.Conv2d(channel_in, channel_out, kernel_size, stride, padding, bias=False)]
        nn.init.xavier_uniform_(layers[0].weight)

    if activation.lower() == 'relu':
        layers += [nn.ReLU(inplace=True)]
    if activation.lower() == 'leakyrelu':
        layers += [nn.LeakyReLU(0.2, inplace=True)]
    if activation.lower() == 'tanh':
        layers += [nn.Tanh()]
    if activation.lower() == 'sigmoid':
        layers += [nn.Sigmoid()]

    return nn.Sequential(*layers)

def upconv2d(params_list, batch_norm = True):
    channel_in, channel_out, kernel_size, stride, padding, activation = params_list
    layers = []
    if batch_norm:
        layers += [nn.ConvTranspose2d(channel_in, channel_out, kernel_size, stride, padding, bias=False),
                   nn.BatchNorm2d(channel_out)]
        nn.init.xavier_uniform_(layers[0].weight)
    else:
        layers += [nn.ConvTranspose2d(channel_in, channel_out, kernel_size, stride, padding, bias=False)]
        nn.init.xavier_uniform_(layers[0].weight)

    if activation.lower() == 'relu':
        layers += [nn.ReLU(inplace=True)]
    if activation.lower() == 'leakyrelu':
        layers += [nn.LeakyReLU(0.2, inplace=True)]
    if activation.lower() == 'tanh':
        layers += [nn.Tanh()]
    if activation.lower() == 'sigmoid':
        layers += [nn.Sigmoid()]

    return nn.Sequential(*layers)

def transpose(ndarray):
    return np.transpose(ndarray, [0,2,3,1])

def gray2rgb(ndarray):
    return np.concatenate((ndarray, ndarray, ndarray), axis=2)

# %% [markdown]
# ### 2.1 Write the code (Generator) [3 points]
# * You need to set the hyperparameters for implementing the upconvolutions (params_list)
# * There are 'ReLU', 'LeakyReLU', 'Tanh', and 'Sigmoid' for the activation functions
# * If you do not want to use the activation function, just put '' in the position of the activation function
# * Other parameters, such as paddings, can be determined by calculating the formulation of convolutional process<br>
#   (See in https://pytorch.org/docs/stable/nn.html)
# * You have to use the functions **conv2d()** or **upconv2d()** which are defined from above

# %%
print('STEP 3-1: CREATE MODEL CLASS (Generator)')


# [input channels, output channels, kernel_size, strides, paddings]

cfg_g_enc_X = [
    [1, 64, 7, 2, 3, 'leakyrelu'],
     [64, 128, 3, 2, 1, 'leakyrelu']
    ]

cfg_g_enc_Y = [
    [3, 64, 7, 2, 3, 'leakyrelu'],
    [64, 128, 3, 2, 1, 'leakyrelu']
]

cfg_g_trans = [
    [128, 128, 3, 1, 1, 'leakyrelu'],
    [128, 128, 3, 1, 1, 'leakyrelu'],
    [128, 128, 3, 1, 1, 'leakyrelu']
]

cfg_g_dec_X = [
    [128, 64, 4, 2, 1, 'leakyrelu'],
    [64, 3, 4, 2, 1, 'tanh']
]

cfg_g_dec_Y =  [
    [128, 64, 4, 2, 1, 'leakyrelu'],
    [64, 1, 4, 2, 1, 'tanh']
]


class Generator_X(nn.Module):
    def __init__(self):
        super(Generator_X, self).__init__()

        #############
        # CODE HERE #
        #############

        self.encoder = nn.Sequential(
            conv2d(cfg_g_enc_X[0], batch_norm=False),  # First convolution layer
            conv2d(cfg_g_enc_X[1], batch_norm=True)   # Second convolution layer
        )

        self.transformer = nn.Sequential(
            conv2d(cfg_g_trans[0], batch_norm=True),  # First ResNet block
            conv2d(cfg_g_trans[1], batch_norm=True),  # Second ResNet block
            conv2d(cfg_g_trans[2], batch_norm=True)   # Third ResNet block
        )

        self.decoder = nn.Sequential(
            upconv2d(cfg_g_dec_X[0], batch_norm=True),  # First upconvolution layer
            upconv2d(cfg_g_dec_X[1], batch_norm=False)  # Second upconvolution layer
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.transformer(x)
        x = self.decoder(x)
        return x

class Generator_Y(nn.Module):
    def __init__(self):
        super(Generator_Y, self).__init__()

        self.encoder = nn.Sequential(
            conv2d(cfg_g_enc_Y[0], batch_norm=False),  # First convolution layer
            conv2d(cfg_g_enc_Y[1], batch_norm=True)   # Second convolution layer
        )

        self.transformer = nn.Sequential(
            conv2d(cfg_g_trans[0], batch_norm=True),  # First ResNet block
            conv2d(cfg_g_trans[1], batch_norm=True),  # Second ResNet block
            conv2d(cfg_g_trans[2], batch_norm=True)   # Third ResNet block
        )

        self.decoder = nn.Sequential(
            upconv2d(cfg_g_dec_Y[0], batch_norm=True),  # First upconvolution layer
            upconv2d(cfg_g_dec_Y[1], batch_norm=False)  # Second upconvolution layer
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.transformer(x)
        x = self.decoder(x)
        return x
# Out:
# STEP 3-1: CREATE MODEL CLASS (Generator)

# %% [markdown]
# ### 2.2 Write the code (Discriminator) [3 points]
# * You need to set the hyperparameters for implementing the convolutions (params_list)
# * There are 'ReLU', 'LeakyReLU', 'Tanh', and 'Sigmoid' for the activation functions
# * If you do not want to use the activation function, just put '' in the position of the activation function
# * Other parameters, such as paddings, can be determined by calculating the formulation of convolutional process<br>
#   (See in https://pytorch.org/docs/stable/nn.html)
# * You have to use the functions **conv2d()** or **upconv2d()** which are defined from above

# %%
print('STEP 3-2: CREATE MODEL CLASS (Discriminator)')


# [input channels, output channels, kernel_size, strides, paddings]

cfg_d_X = [
    [1, 64, 4, 2, 1, 'leakyrelu'],
    [64, 128, 4, 2, 1, 'leakyrelu'],
    [128, 256, 4, 1, 2, 'leakyrelu'],
    [256, 1, 1, 1, 0, 'sigmoid']
]

cfg_d_Y = [
    [3, 64, 4, 2, 1, 'leakyrelu'],
    [64, 128, 4, 2, 1, 'leakyrelu'],
    [128, 256, 4, 1, 1, 'leakyrelu'],
    [256, 1, 4, 1, 0, 'sigmoid']
]


class Discriminator_X(nn.Module):
    def __init__(self):
        super(Discriminator_X, self).__init__()

        #############
        # CODE HERE #
        #############
        self.model = nn.Sequential(
            conv2d(cfg_d_X[0], batch_norm=False),  # First convolution layer
            conv2d(cfg_d_X[1], batch_norm=True),   # Second convolution layer
            conv2d(cfg_d_X[2], batch_norm=True),   # Third convolution layer
            conv2d(cfg_d_X[3], batch_norm=False)   # Final convolution layer (Sigmoid activation)
        )

    def forward(self, x):

        #############
        # CODE HERE #
        #############
        return self.model(x)

class Discriminator_Y(nn.Module):
    def __init__(self):
        super(Discriminator_Y, self).__init__()

        #############
        # CODE HERE #
        #############
        self.model = nn.Sequential(
            conv2d(cfg_d_Y[0], batch_norm=False),  # First convolution layer
            conv2d(cfg_d_Y[1], batch_norm=True),   # Second convolution layer
            conv2d(cfg_d_Y[2], batch_norm=True),   # Third convolution layer
            conv2d(cfg_d_Y[3], batch_norm=False)   # Final convolution layer (Sigmoid activation)
        )

    def forward(self, x):

        #############
        # CODE HERE #
        #############
        return self.model(x)
# Out:
# STEP 3-2: CREATE MODEL CLASS (Discriminator)

# %%
print('STEP 4: INSTANTIATE MODEL CLASS')


model_G_X = Generator_X()
model_G_Y = Generator_Y()
model_D_X = Discriminator_X()
model_D_Y = Discriminator_Y()


#######################
#  USE GPU FOR MODEL  #
#######################


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_G_X.to(device)
print(model_G_X)
model_G_Y.to(device)
print(model_G_Y)
model_D_X.to(device)
print(model_D_X)
model_D_Y.to(device)
# Out:
# STEP 4: INSTANTIATE MODEL CLASS
# Generator_X(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (transformer): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
# )
# Generator_Y(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (transformer): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
# )
# Discriminator_X(
#   (model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Sigmoid()
#     )
#   )
# )
# Discriminator_Y(
#   (model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): Sigmoid()
#     )
#   )
# )

# %%
print('STEP 5: INSTANTIATE LOSS CLASS')

criterion_GAN = nn.BCELoss()
criterion_L1 = nn.L1Loss()

print('STEP 6: INSTANTIATE OPTIMIZER CLASS')

optimizer_G_X = torch.optim.Adam(model_G_X.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_G_Y = torch.optim.Adam(model_G_Y.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_D_X = torch.optim.Adam(model_D_X.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_D_Y = torch.optim.Adam(model_D_Y.parameters(), lr=lr, betas=(beta1, 0.999))
# Out:
# STEP 5: INSTANTIATE LOSS CLASS
# STEP 6: INSTANTIATE OPTIMIZER CLASS

# %% [markdown]
# ### 2.3 Train the Cycle GAN [4 points]
# * After the training is finished, check out the generated samples
# * If the samples are generated well, then you will get the full score
# * 1.2GB of GPU memory
# * 10~20 mins of training
# * Output samples
# <img src="https://drive.google.com/uc?id=1PAmQ4XGHH6w24KrFvNOmUER2SAhKp_xN" alt="no_image" style="width: 600px;"/><br>

# %%
print('STEP 7: TRAIN THE MODEL')

label_real = torch.full((bs, 1, 8, 8), real_label, dtype=torch.float32, device=device)
label_fake = torch.full((bs, 1, 8, 8), fake_label, dtype=torch.float32, device=device)

num_iter = 0
max_iter = num_epochs*len(train_X_loader)

train_start_time = time.time()
for epoch in range(1, num_epochs+1):
    for batch_index, data_X in enumerate(train_X_loader):
        model_G_X.train()
        model_G_Y.train()
        model_D_X.train()
        model_D_Y.train()

        data_X = data_X[0].to(device)
        data_Y = next(iter(train_Y_loader))[0].to(device)

        ### Update discriminator model

        #############
        # CODE HERE #
        #############
        if batch_index == 0 and epoch == 1:
            with torch.no_grad():
                # D_X용 label
                pred_shape_X = model_D_X(data_X).shape
                label_real_X = torch.full((bs, 1, pred_shape_X[2], pred_shape_X[3]),
                                       real_label, dtype=torch.float32, device=device)
                label_fake_X = torch.full((bs, 1, pred_shape_X[2], pred_shape_X[3]),
                                       fake_label, dtype=torch.float32, device=device)

                # D_Y용 label
                pred_shape_Y = model_D_Y(data_Y).shape
                label_real_Y = torch.full((bs, 1, pred_shape_Y[2], pred_shape_Y[3]),
                                       real_label, dtype=torch.float32, device=device)
                label_fake_Y = torch.full((bs, 1, pred_shape_Y[2], pred_shape_Y[3]),
                                       fake_label, dtype=torch.float32, device=device)

        optimizer_D_X.zero_grad()
        pred_real_X = model_D_X(data_X)
        loss_D_X_real = criterion_GAN(pred_real_X, label_real_X)

        fake_X = model_G_Y(data_Y)
        pred_fake_X = model_D_X(fake_X.detach())
        loss_D_X_fake = criterion_GAN(pred_fake_X, label_fake_X)

        loss_D_X = loss_D_X_real + loss_D_X_fake
        loss_D_X.backward()
        optimizer_D_X.step()

        # Update D_Y
        optimizer_D_Y.zero_grad()
        pred_real_Y = model_D_Y(data_Y)
        loss_D_Y_real = criterion_GAN(pred_real_Y, label_real_Y)

        fake_Y = model_G_X(data_X)
        pred_fake_Y = model_D_Y(fake_Y.detach())
        loss_D_Y_fake = criterion_GAN(pred_fake_Y, label_fake_Y)

        loss_D_Y = loss_D_Y_real + loss_D_Y_fake
        loss_D_Y.backward()
        optimizer_D_Y.step()

        err_D = loss_D_X + loss_D_Y

        ### Update generator model

        #############
        # CODE HERE #
        #############
        # Update G_X and G_Y
        optimizer_G_X.zero_grad()
        optimizer_G_Y.zero_grad()

        # GAN loss
        fake_X = model_G_Y(data_Y)
        pred_fake_X = model_D_X(fake_X)
        loss_G_Y = criterion_GAN(pred_fake_X, label_real_X)

        fake_Y = model_G_X(data_X)
        pred_fake_Y = model_D_Y(fake_Y)
        loss_G_X = criterion_GAN(pred_fake_Y, label_real_Y)

        # Cycle consistency loss
        reconstructed_X = model_G_Y(fake_Y)
        loss_cycle_X = criterion_L1(reconstructed_X, data_X)

        reconstructed_Y = model_G_X(fake_X)
        loss_cycle_Y = criterion_L1(reconstructed_Y, data_Y)

        loss_cycle = loss_cycle_X + loss_cycle_Y
        loss_G = loss_G_X + loss_G_Y + 10 * loss_cycle

        loss_G.backward()
        optimizer_G_X.step()
        optimizer_G_Y.step()

        err_G = loss_G_X + loss_G_Y

        err_C = loss_cycle

        num_iter += 1
        # Output training stats
        if num_iter%100 == 0:
            print('it[{:04d}/{:04d}] \tLoss_D:{:.4f} \tLoss_G:{:.4f} \tLoss_C:{:.4f} \telapsed_time:{:.2f}mins'.format(
                num_iter, max_iter, err_D.item(), err_G.item(), err_C.item(), (time.time()-train_start_time)/60
            ))

        if num_iter%1000==0 or num_iter==max_iter:
            save_name = osp.join(save_dir, 'it{:04d}.pt'.format(num_iter))
            torch.save({
                'model_G_X': model_G_X.state_dict(),
                'model_G_Y': model_G_Y.state_dict()
            }, save_name)

            with torch.no_grad():
                model_G_X.eval()
                model_G_Y.eval()
                for test_index, data_X in enumerate(test_X_loader):
                    if test_index == 0:

                        data_X = data_X[0].to(device)
                        data_Y = next(iter(test_Y_loader))[0].to(device)

                        output_X = model_G_X(data_X)
                        output_Y = model_G_Y(data_Y)

                        data_X = ((data_X+1)/2).cpu().data.numpy()
                        data_Y = ((data_Y+1)/2).cpu().data.numpy()

                        output_X = ((output_X + 1)/2).cpu().data.numpy()
                        output_Y = ((output_Y + 1)/2).cpu().data.numpy()

                        for vis_idx in range(vis_num):
                            data_X_, data_Y_ = gray2rgb(transpose(data_X)[vis_idx]), transpose(data_Y)[vis_idx]
                            output_X_, output_Y_  = transpose(output_X)[vis_idx], gray2rgb(transpose(output_Y)[vis_idx])
                            outputs = np.concatenate((data_X_, output_X_, data_Y_, output_Y_), axis=1)
                            plt.imshow(outputs)
                            plt.pause(0.001)
# Out:
# STEP 7: TRAIN THE MODEL
# it[0100/4685] 	Loss_D:2.3002 	Loss_G:2.4102 	Loss_C:0.3107 	elapsed_time:0.13mins
# it[0200/4685] 	Loss_D:2.2554 	Loss_G:2.3793 	Loss_C:0.2354 	elapsed_time:0.25mins
# it[0300/4685] 	Loss_D:1.8196 	Loss_G:3.3062 	Loss_C:0.2288 	elapsed_time:0.37mins
# it[0400/4685] 	Loss_D:1.7400 	Loss_G:3.9312 	Loss_C:0.2776 	elapsed_time:0.49mins
# it[0500/4685] 	Loss_D:1.6470 	Loss_G:3.4891 	Loss_C:0.2580 	elapsed_time:0.61mins
# it[0600/4685] 	Loss_D:1.4344 	Loss_G:4.0518 	Loss_C:0.2431 	elapsed_time:0.73mins
# it[0700/4685] 	Loss_D:1.4484 	Loss_G:4.9548 	Loss_C:0.2390 	elapsed_time:0.85mins
# it[0800/4685] 	Loss_D:1.5512 	Loss_G:3.9895 	Loss_C:0.2662 	elapsed_time:0.97mins
# it[0900/4685] 	Loss_D:1.6079 	Loss_G:4.5989 	Loss_C:0.2548 	elapsed_time:1.08mins
# it[1000/4685] 	Loss_D:1.4592 	Loss_G:4.1546 	Loss_C:0.2652 	elapsed_time:1.20mins
# it[1100/4685] 	Loss_D:1.2717 	Loss_G:3.9516 	Loss_C:0.2569 	elapsed_time:1.36mins
# it[1200/4685] 	Loss_D:1.4454 	Loss_G:4.0280 	Loss_C:0.2460 	elapsed_time:1.48mins
# it[1300/4685] 	Loss_D:1.3855 	Loss_G:4.1077 	Loss_C:0.2444 	elapsed_time:1.60mins
# it[1400/4685] 	Loss_D:1.5312 	Loss_G:3.7196 	Loss_C:0.2650 	elapsed_time:1.71mins
# it[1500/4685] 	Loss_D:1.5026 	Loss_G:3.6091 	Loss_C:0.2546 	elapsed_time:1.84mins
# it[1600/4685] 	Loss_D:1.7709 	Loss_G:3.5360 	Loss_C:0.2565 	elapsed_time:1.95mins
# it[1700/4685] 	Loss_D:2.1301 	Loss_G:2.1634 	Loss_C:0.2759 	elapsed_time:2.07mins
# it[1800/4685] 	Loss_D:1.5787 	Loss_G:3.8907 	Loss_C:0.2649 	elapsed_time:2.19mins
# it[1900/4685] 	Loss_D:2.2574 	Loss_G:2.6385 	Loss_C:0.2506 	elapsed_time:2.31mins
# it[2000/4685] 	Loss_D:1.4698 	Loss_G:3.5956 	Loss_C:0.2622 	elapsed_time:2.42mins
# it[2100/4685] 	Loss_D:1.4582 	Loss_G:3.6433 	Loss_C:0.2736 	elapsed_time:2.60mins
# it[2200/4685] 	Loss_D:1.5041 	Loss_G:3.7624 	Loss_C:0.2713 	elapsed_time:2.72mins
# it[2300/4685] 	Loss_D:1.5833 	Loss_G:3.6511 	Loss_C:0.2737 	elapsed_time:2.83mins
# it[2400/4685] 	Loss_D:1.4384 	Loss_G:3.8679 	Loss_C:0.2582 	elapsed_time:2.95mins
# it[2500/4685] 	Loss_D:1.7300 	Loss_G:3.6615 	Loss_C:0.2516 	elapsed_time:3.07mins
# it[2600/4685] 	Loss_D:1.3393 	Loss_G:3.6374 	Loss_C:0.2561 	elapsed_time:3.19mins
# it[2700/4685] 	Loss_D:1.5161 	Loss_G:3.7462 	Loss_C:0.2579 	elapsed_time:3.31mins
# it[2800/4685] 	Loss_D:1.6092 	Loss_G:4.3087 	Loss_C:0.2729 	elapsed_time:3.43mins
# it[2900/4685] 	Loss_D:1.6551 	Loss_G:5.0068 	Loss_C:0.2580 	elapsed_time:3.55mins
# it[3000/4685] 	Loss_D:1.8985 	Loss_G:2.7714 	Loss_C:0.2655 	elapsed_time:3.66mins
# it[3100/4685] 	Loss_D:1.6155 	Loss_G:3.6094 	Loss_C:0.2630 	elapsed_time:3.83mins
# it[3200/4685] 	Loss_D:1.5198 	Loss_G:4.6812 	Loss_C:0.2600 	elapsed_time:3.94mins
# it[3300/4685] 	Loss_D:1.2184 	Loss_G:4.2552 	Loss_C:0.2653 	elapsed_time:4.06mins
# it[3400/4685] 	Loss_D:1.6040 	Loss_G:5.4583 	Loss_C:0.2721 	elapsed_time:4.18mins
# it[3500/4685] 	Loss_D:1.3149 	Loss_G:3.6118 	Loss_C:0.2583 	elapsed_time:4.30mins
# it[3600/4685] 	Loss_D:1.3498 	Loss_G:2.9037 	Loss_C:0.2659 	elapsed_time:4.42mins
# it[3700/4685] 	Loss_D:1.4283 	Loss_G:3.8676 	Loss_C:0.2614 	elapsed_time:4.54mins
# it[3800/4685] 	Loss_D:1.3962 	Loss_G:3.3980 	Loss_C:0.2686 	elapsed_time:4.66mins
# it[3900/4685] 	Loss_D:1.2231 	Loss_G:4.4584 	Loss_C:0.2750 	elapsed_time:4.77mins
# it[4000/4685] 	Loss_D:1.3118 	Loss_G:4.2699 	Loss_C:0.2673 	elapsed_time:4.89mins
# it[4100/4685] 	Loss_D:1.3506 	Loss_G:3.6634 	Loss_C:0.2702 	elapsed_time:5.05mins
# it[4200/4685] 	Loss_D:1.7484 	Loss_G:3.0115 	Loss_C:0.2790 	elapsed_time:5.17mins
# it[4300/4685] 	Loss_D:1.1542 	Loss_G:4.5419 	Loss_C:0.2614 	elapsed_time:5.29mins
# it[4400/4685] 	Loss_D:1.3509 	Loss_G:3.7950 	Loss_C:0.2743 	elapsed_time:5.40mins
# it[4500/4685] 	Loss_D:1.2210 	Loss_G:4.1126 	Loss_C:0.2677 	elapsed_time:5.53mins
# it[4600/4685] 	Loss_D:1.2421 	Loss_G:4.1068 	Loss_C:0.2671 	elapsed_time:5.64mins
