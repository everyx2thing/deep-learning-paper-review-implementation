# %% [markdown]
# #LAB 2: YOLO detection model

# %% [markdown]
# <h4><div style="text-align: right"> Due date: 15:00 Oct 28, 2025.  </div> <br>
#
#
#
# <div style="text-align: right"> Please upload your file and final-report at PLATO before the class in the form of [ID_Name_Lab2.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - You must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[202355532] [THADAR SOE]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2025-10-27 15:12:42.913911

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip -q "/content/drive/MyDrive/lab2.zip" -d "/lab2"
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable
import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = 'input your GPU id' # 반드시 지정된 GPU만 사용하세요. Please use only the designated GPU.

# %%
class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])

        with open(list_file) as f:
            lines = f.readlines()

        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)

    def img_pre_process(self, img, boxes, labels):

        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr

        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)

        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)

            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))

            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]

            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]

            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]

            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]

            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range

            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift

                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in

        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))

            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped

        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes)  # Normalize the bounding box coordinates (0 to 1) by dividing by image width and height.
        target = torch.zeros((grid_size, grid_size, 30)) # Initialize the target tensor with shape (7, 7, 30)
        cell_size = 1./grid_size  # Define the size of each grid cell in the normalized image space.

        wh = boxes[:,2:] - boxes[:,:2] # Calculate width and height of each bounding box.
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2 # Calculate center coordinates (cx, cy) of each bounding box.

        for i in range(cxcy.size()[0]): # Iterate over each bounding box in the image.
            cxcy_sample = cxcy[i] # Extract the center (cx, cy) of the current bounding box.
            ij = (cxcy_sample/cell_size).ceil()-1 # Determine which grid cell (i, j) the center (cx, cy) falls into.
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1

            xy = ij*cell_size # Calculate the top-left corner of the grid cell.
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy

        return target

    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)

        target = self.generate_target(img, boxes, labels) # 7x7x30

        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1

        return img, target

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()

        self.pre_train_net = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Max Pool 1 -> 112x112x64
    nn.MaxPool2d(kernel_size=2, stride=2),

    # Conv 2: 3x3x192, pad=1 -> 112x112x192
    nn.Conv2d(64, 192, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Max Pool 2 -> 56x56x192
    nn.MaxPool2d(kernel_size=2, stride=2),

    # Conv 3: 1x1x128
    nn.Conv2d(192, 128, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 4: 3x3x256
    nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 5: 1x1x256
    nn.Conv2d(256, 256, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 6: 3x3x512
    nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Max Pool 3 -> 28x28x512
    nn.MaxPool2d(kernel_size=2, stride=2),

    # Conv 7: 1x1x256
    nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 8: 3x3x512
    nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 9: 1x1x256
    nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 10: 3x3x512
    nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 11: 1x1x256
    nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 12: 3x3x512
    nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 13: 1x1x256
    nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 14: 3x3x512
    nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 15: 1x1x512
    nn.Conv2d(512, 512, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 16: 3x3x1024
    nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Max Pool 4 -> 14x14x1024
    nn.MaxPool2d(kernel_size=2, stride=2),

    # Conv 17: 1x1x512
    nn.Conv2d(1024, 512, kernel_size=1, stride=1, padding=0, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 18: 3x3x1024
    nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),

        )

        self.post_net = nn.Sequential(
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 20: 3x3x1024, stride=2 -> 7x7x1024
    nn.Conv2d(1024, 1024, kernel_size=3, stride=2, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 21: 3x3x1024
    nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
    # Conv 22: 3x3x1024
    nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1, bias=True),
    nn.LeakyReLU(negative_slope=0.1, inplace=True),
        )

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()

        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj

    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        pred_cls = pred[contain].contiguous().view(-1, 30)[:, 10:]
        tgt_cls  = target[contain].contiguous().view(-1, 30)[:, 10:]
        prob_loss = F.mse_loss(pred_cls, tgt_cls, size_average=False)

        return prob_loss # F.mse_loss(input, target, size_average=False)

    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        flat_pred   = pred[not_contain].contiguous().view(-1, 30)
        flat_target = target[not_contain].contiguous().view(-1, 30)

        noobj_loss1_box1 = F.mse_loss(flat_pred[:, 4], flat_target[:, 4], size_average=False)
        noobj_loss1_box2 = F.mse_loss(flat_pred[:, 9], flat_target[:, 9], size_average=False)
        noobj_loss1 = noobj_loss1_box1 + noobj_loss1_box2

        return noobj_loss1  # F.mse_loss(input, target, size_average=False)


    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping

        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)

        # Note that, We assign one predictor to be "responsible" for predicting
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables

        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_()

        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence
                                                                   # of the cell which contains object

        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            box_p_coord[:,:2] = box_p[:, :2] - box_p[:, 2:4] / 2.0
            box_p_coord[:,2:4] = box_p[:, :2] + box_p[:, 2:4] / 2.0

            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:,:2] = box_t[:, :2] - box_t[:, 2:4] / 2.0
            box_t_coord[:,2:4] = box_t[:, :2] + box_t[:, 2:4] / 2.0

            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes,

            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1

            target_iou_gt[i+max_idx] = gt_iou.data.cuda()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)

        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1, 5)

        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1, 5)

        ## For target domain
        contain_box_target = box_target[contain_obj_mask].view(-1, 5)
        not_contain_box_target = box_target[contain_noobj_mask].view(-1, 5)
        not_contain_box_target[:,4] = 0

        ## For the GT IoU
        contain_iou_target = target_iou_gt[contain_obj_mask[:, 4]].view(-1)

        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)

        return obj_loss, xy_loss, wh_loss, noobj_loss2

    def compute_iou(self, box_p, box_t):

        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]

        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)

        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]

        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]

        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0

        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)

        iou = inter_area / (pred_area + target_area - inter_area)

        return iou



    def forward(self,pred,target):

        batch_size = pred.size()[0]

        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)

        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)

        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
file_root = '../lab2/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='../lab2/utils/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('../lab2/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=10.0)
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:14.4742, average_loss: 203.4847
# Epoch [1/15], Iter [20,430] Loss:4.7436, average_loss: 105.0017
# Epoch [1/15], Iter [30,430] Loss:2.5627, average_loss: 71.0565
# Epoch [1/15], Iter [40,430] Loss:2.1267, average_loss: 53.7904
# Epoch [1/15], Iter [50,430] Loss:1.6915, average_loss: 43.4207
# Epoch [1/15], Iter [60,430] Loss:1.7596, average_loss: 36.5469
# Epoch [1/15], Iter [70,430] Loss:2.0108, average_loss: 31.6233
# Epoch [1/15], Iter [80,430] Loss:1.1783, average_loss: 27.8966
# Epoch [1/15], Iter [90,430] Loss:1.5994, average_loss: 24.9923
# Epoch [1/15], Iter [100,430] Loss:2.0836, average_loss: 22.6534
# Epoch [1/15], Iter [110,430] Loss:1.9395, average_loss: 20.7159
# Epoch [1/15], Iter [120,430] Loss:1.7937, average_loss: 19.1217
# Epoch [1/15], Iter [130,430] Loss:1.4002, average_loss: 17.7575
# Epoch [1/15], Iter [140,430] Loss:1.6009, average_loss: 16.5970
# Epoch [1/15], Iter [150,430] Loss:1.4606, average_loss: 15.5754
# Epoch [1/15], Iter [160,430] Loss:1.3295, average_loss: 14.6749
# Epoch [1/15], Iter [170,430] Loss:1.8264, average_loss: 13.8924
# Epoch [1/15], Iter [180,430] Loss:1.1392, average_loss: 13.1798
# Epoch [1/15], Iter [190,430] Loss:0.9812, average_loss: 12.5513
# Epoch [1/15], Iter [200,430] Loss:0.8524, average_loss: 11.9771
# Epoch [1/15], Iter [210,430] Loss:1.0036, average_loss: 11.4565
# Epoch [1/15], Iter [220,430] Loss:1.1020, average_loss: 10.9931
# Epoch [1/15], Iter [230,430] Loss:1.0488, average_loss: 10.5633
# Epoch [1/15], Iter [240,430] Loss:0.6899, average_loss: 10.1736
# Epoch [1/15], Iter [250,430] Loss:0.8845, average_loss: 9.8127
# Epoch [1/15], Iter [260,430] Loss:1.0711, average_loss: 9.4763
# Epoch [1/15], Iter [270,430] Loss:0.8617, average_loss: 9.1568
# Epoch [1/15], Iter [280,430] Loss:0.6807, average_loss: 8.8577
# Epoch [1/15], Iter [290,430] Loss:0.6603, average_loss: 8.5860
# Epoch [3/15], Iter [270,430] Loss:0.6086, average_loss: 0.6438
# Epoch [3/15], Iter [280,430] Loss:0.4376, average_loss: 0.6440
# Epoch [3/15], Iter [290,430] Loss:1.3578, average_loss: 0.6426
# Epoch [3/15], Iter [300,430] Loss:1.4158, average_loss: 0.6445
# Epoch [3/15], Iter [310,430] Loss:0.5659, average_loss: 0.6452
# Epoch [3/15], Iter [320,430] Loss:0.5972, average_loss: 0.6478
# Epoch [3/15], Iter [330,430] Loss:0.7301, average_loss: 0.6466
# Epoch [3/15], Iter [340,430] Loss:0.9473, average_loss: 0.6482
# Epoch [3/15], Iter [350,430] Loss:0.6820, average_loss: 0.6450
# Epoch [3/15], Iter [360,430] Loss:0.4926, average_loss: 0.6469
# Epoch [3/15], Iter [370,430] Loss:0.6001, average_loss: 0.6485
# Epoch [3/15], Iter [380,430] Loss:0.5989, average_loss: 0.6495
# Epoch [3/15], Iter [390,430] Loss:0.7076, average_loss: 0.6500
# Epoch [3/15], Iter [400,430] Loss:0.8223, average_loss: 0.6504
# Epoch [3/15], Iter [410,430] Loss:0.7066, average_loss: 0.6486
# Epoch [3/15], Iter [420,430] Loss:1.0140, average_loss: 0.6510
# Epoch [3/15], Iter [430,430] Loss:0.3900, average_loss: 0.6526
# Epoch [4/15], Iter [10,430] Loss:0.4414, average_loss: 0.5645
# Epoch [4/15], Iter [20,430] Loss:0.5291, average_loss: 0.5200
# Epoch [4/15], Iter [30,430] Loss:0.4684, average_loss: 0.5032
# Epoch [4/15], Iter [40,430] Loss:0.7762, average_loss: 0.5287
# Epoch [4/15], Iter [50,430] Loss:0.5634, average_loss: 0.5346
# Epoch [4/15], Iter [60,430] Loss:0.8304, average_loss: 0.5499
# Epoch [4/15], Iter [70,430] Loss:0.7402, average_loss: 0.5555
# Epoch [4/15], Iter [80,430] Loss:0.4992, average_loss: 0.5682
# Epoch [4/15], Iter [90,430] Loss:0.2526, average_loss: 0.5645
# Epoch [4/15], Iter [100,430] Loss:0.5350, average_loss: 0.5797
# Epoch [4/15], Iter [110,430] Loss:0.7584, average_loss: 0.5859
# Epoch [4/15], Iter [120,430] Loss:0.3734, average_loss: 0.5910
# Epoch [4/15], Iter [130,430] Loss:0.9439, average_loss: 0.5930
# Epoch [4/15], Iter [140,430] Loss:0.6745, average_loss: 0.6000
# Epoch [4/15], Iter [150,430] Loss:0.7458, average_loss: 0.6120
# Epoch [4/15], Iter [160,430] Loss:0.4303, average_loss: 0.6122
# Epoch [4/15], Iter [170,430] Loss:0.4359, average_loss: 0.6144
# Epoch [4/15], Iter [180,430] Loss:0.7115, average_loss: 0.6167
# Epoch [4/15], Iter [190,430] Loss:0.5832, average_loss: 0.6132
# Epoch [4/15], Iter [200,430] Loss:1.0110, average_loss: 0.6139
# Epoch [4/15], Iter [210,430] Loss:0.4126, average_loss: 0.6132
# Epoch [4/15], Iter [220,430] Loss:0.4934, average_loss: 0.6122
# Epoch [4/15], Iter [230,430] Loss:0.6549, average_loss: 0.6111
# Epoch [4/15], Iter [240,430] Loss:0.5483, average_loss: 0.6107
# Epoch [4/15], Iter [250,430] Loss:0.4812, average_loss: 0.6097
# Epoch [4/15], Iter [260,430] Loss:0.6791, average_loss: 0.6105
# Epoch [4/15], Iter [270,430] Loss:0.5669, average_loss: 0.6125
# Epoch [4/15], Iter [280,430] Loss:1.0981, average_loss: 0.6154
# Epoch [4/15], Iter [290,430] Loss:0.4716, average_loss: 0.6186
# Epoch [4/15], Iter [300,430] Loss:0.9019, average_loss: 0.6212
# Epoch [4/15], Iter [310,430] Loss:0.6708, average_loss: 0.6232
# Epoch [4/15], Iter [320,430] Loss:1.1057, average_loss: 0.6240
# Epoch [4/15], Iter [330,430] Loss:0.4705, average_loss: 0.6234
# Epoch [4/15], Iter [340,430] Loss:0.8139, average_loss: 0.6255
# Epoch [4/15], Iter [350,430] Loss:0.6958, average_loss: 0.6276
# Epoch [4/15], Iter [360,430] Loss:0.4569, average_loss: 0.6257
# Epoch [4/15], Iter [370,430] Loss:0.7043, average_loss: 0.6316
# Epoch [4/15], Iter [380,430] Loss:0.5814, average_loss: 0.6333
# Epoch [4/15], Iter [390,430] Loss:0.6537, average_loss: 0.6313
# Epoch [4/15], Iter [400,430] Loss:1.1774, average_loss: 0.6344
# Epoch [4/15], Iter [410,430] Loss:0.3943, average_loss: 0.6334
# Epoch [4/15], Iter [420,430] Loss:0.4987, average_loss: 0.6316
# Epoch [4/15], Iter [430,430] Loss:0.8101, average_loss: 0.6314
# Epoch [5/15], Iter [10,430] Loss:0.3755, average_loss: 0.5504
# Epoch [5/15], Iter [20,430] Loss:0.5649, average_loss: 0.5444
# Epoch [5/15], Iter [30,430] Loss:0.3670, average_loss: 0.5664
# Epoch [5/15], Iter [40,430] Loss:0.8493, average_loss: 0.5871
# Epoch [5/15], Iter [50,430] Loss:0.4920, average_loss: 0.5976
# Epoch [5/15], Iter [60,430] Loss:1.1815, average_loss: 0.6197
# Epoch [5/15], Iter [70,430] Loss:0.6242, average_loss: 0.6174
# Epoch [5/15], Iter [80,430] Loss:0.8226, average_loss: 0.6162
# Epoch [5/15], Iter [90,430] Loss:0.8270, average_loss: 0.6347
# Epoch [5/15], Iter [100,430] Loss:0.5997, average_loss: 0.6207
# Epoch [5/15], Iter [110,430] Loss:0.7132, average_loss: 0.6159
# Epoch [5/15], Iter [120,430] Loss:0.5937, average_loss: 0.6126
# Epoch [5/15], Iter [130,430] Loss:0.8285, average_loss: 0.6185
# Epoch [5/15], Iter [140,430] Loss:0.4849, average_loss: 0.6251
# Epoch [5/15], Iter [150,430] Loss:1.0708, average_loss: 0.6253
# Epoch [5/15], Iter [160,430] Loss:0.3423, average_loss: 0.6265
# Epoch [5/15], Iter [170,430] Loss:0.7137, average_loss: 0.6265
# Epoch [5/15], Iter [180,430] Loss:0.9053, average_loss: 0.6245
# Epoch [5/15], Iter [190,430] Loss:0.7598, average_loss: 0.6255
# Epoch [5/15], Iter [200,430] Loss:0.7087, average_loss: 0.6251
# Epoch [5/15], Iter [210,430] Loss:0.4653, average_loss: 0.6215
# Epoch [5/15], Iter [220,430] Loss:0.5856, average_loss: 0.6179
# Epoch [5/15], Iter [230,430] Loss:0.4277, average_loss: 0.6164
# Epoch [5/15], Iter [240,430] Loss:0.9912, average_loss: 0.6149
# Epoch [5/15], Iter [250,430] Loss:0.8458, average_loss: 0.6132
# Epoch [5/15], Iter [260,430] Loss:0.6730, average_loss: 0.6167
# Epoch [5/15], Iter [270,430] Loss:0.5480, average_loss: 0.6140
# Epoch [5/15], Iter [280,430] Loss:0.7538, average_loss: 0.6148
# Epoch [5/15], Iter [290,430] Loss:0.7404, average_loss: 0.6192
# Epoch [5/15], Iter [300,430] Loss:0.9035, average_loss: 0.6188
# Epoch [5/15], Iter [310,430] Loss:0.4305, average_loss: 0.6202
# Epoch [5/15], Iter [320,430] Loss:1.3044, average_loss: 0.6217
# Epoch [5/15], Iter [330,430] Loss:0.4451, average_loss: 0.6179
# Epoch [5/15], Iter [340,430] Loss:0.6240, average_loss: 0.6165
# Epoch [5/15], Iter [350,430] Loss:0.7327, average_loss: 0.6194
# Epoch [5/15], Iter [360,430] Loss:0.8964, average_loss: 0.6177
# Epoch [5/15], Iter [370,430] Loss:0.4875, average_loss: 0.6129
# Epoch [5/15], Iter [380,430] Loss:0.5005, average_loss: 0.6128
# Epoch [5/15], Iter [390,430] Loss:0.8056, average_loss: 0.6116
# Epoch [5/15], Iter [400,430] Loss:0.4115, average_loss: 0.6099
# Epoch [5/15], Iter [410,430] Loss:0.4596, average_loss: 0.6120
# Epoch [5/15], Iter [420,430] Loss:0.3734, average_loss: 0.6129
# Epoch [5/15], Iter [430,430] Loss:0.6419, average_loss: 0.6094
# Epoch [6/15], Iter [10,430] Loss:0.5188, average_loss: 0.6315
# Epoch [6/15], Iter [20,430] Loss:0.6125, average_loss: 0.6175
# Epoch [6/15], Iter [30,430] Loss:0.6852, average_loss: 0.5985
# Epoch [6/15], Iter [40,430] Loss:0.8260, average_loss: 0.6157
# Epoch [6/15], Iter [50,430] Loss:0.3792, average_loss: 0.6268
# Epoch [6/15], Iter [60,430] Loss:1.1100, average_loss: 0.6126
# Epoch [6/15], Iter [70,430] Loss:0.6366, average_loss: 0.6122
# Epoch [6/15], Iter [80,430] Loss:0.8333, average_loss: 0.6251
# Epoch [6/15], Iter [90,430] Loss:0.6931, average_loss: 0.6255
# Epoch [6/15], Iter [100,430] Loss:0.6501, average_loss: 0.6159
# Epoch [6/15], Iter [110,430] Loss:0.5627, average_loss: 0.6115
# Epoch [6/15], Iter [120,430] Loss:0.4618, average_loss: 0.6090
# Epoch [6/15], Iter [130,430] Loss:1.1258, average_loss: 0.6074
# Epoch [6/15], Iter [140,430] Loss:1.0935, average_loss: 0.6099
# Epoch [6/15], Iter [150,430] Loss:0.5611, average_loss: 0.6061
# Epoch [6/15], Iter [160,430] Loss:0.4204, average_loss: 0.5986
# Epoch [6/15], Iter [170,430] Loss:0.7725, average_loss: 0.6019
# Epoch [6/15], Iter [180,430] Loss:0.6369, average_loss: 0.6049
# Epoch [6/15], Iter [190,430] Loss:1.3587, average_loss: 0.6058
# Epoch [6/15], Iter [200,430] Loss:0.6177, average_loss: 0.6045
# Epoch [6/15], Iter [210,430] Loss:0.8258, average_loss: 0.6092
# Epoch [6/15], Iter [220,430] Loss:0.6204, average_loss: 0.6064
# Epoch [7/15], Iter [210,430] Loss:0.2962, average_loss: 0.5931
# Epoch [7/15], Iter [220,430] Loss:0.4874, average_loss: 0.5897
# Epoch [7/15], Iter [230,430] Loss:1.0341, average_loss: 0.5884
# Epoch [7/15], Iter [240,430] Loss:0.6453, average_loss: 0.5863
# Epoch [7/15], Iter [250,430] Loss:0.5994, average_loss: 0.5873
# Epoch [7/15], Iter [260,430] Loss:0.8364, average_loss: 0.5876
# Epoch [7/15], Iter [270,430] Loss:0.8344, average_loss: 0.5866
# Epoch [7/15], Iter [280,430] Loss:0.4761, average_loss: 0.5870
# Epoch [7/15], Iter [290,430] Loss:0.6012, average_loss: 0.5832
# Epoch [7/15], Iter [300,430] Loss:0.4899, average_loss: 0.5837
# Epoch [7/15], Iter [310,430] Loss:0.7575, average_loss: 0.5859
# Epoch [7/15], Iter [320,430] Loss:0.5487, average_loss: 0.5892
# Epoch [7/15], Iter [330,430] Loss:0.5883, average_loss: 0.5864
# Epoch [7/15], Iter [340,430] Loss:0.6221, average_loss: 0.5905
# Epoch [7/15], Iter [350,430] Loss:0.4292, average_loss: 0.5890
# Epoch [7/15], Iter [360,430] Loss:0.5624, average_loss: 0.5887
# Epoch [7/15], Iter [370,430] Loss:0.5720, average_loss: 0.5889
# Epoch [7/15], Iter [380,430] Loss:0.4004, average_loss: 0.5873
# Epoch [7/15], Iter [390,430] Loss:1.0616, average_loss: 0.5898
# Epoch [7/15], Iter [400,430] Loss:0.5246, average_loss: 0.5883
# Epoch [7/15], Iter [410,430] Loss:0.5210, average_loss: 0.5879
# Epoch [7/15], Iter [420,430] Loss:0.4045, average_loss: 0.5865
# Epoch [7/15], Iter [430,430] Loss:0.4867, average_loss: 0.5851
# Epoch [8/15], Iter [10,430] Loss:0.7204, average_loss: 0.5836
# Epoch [8/15], Iter [20,430] Loss:0.5069, average_loss: 0.5440
# Epoch [8/15], Iter [30,430] Loss:0.4265, average_loss: 0.5441
# Epoch [8/15], Iter [40,430] Loss:0.2985, average_loss: 0.5241
# Epoch [8/15], Iter [50,430] Loss:0.8876, average_loss: 0.5267
# Epoch [8/15], Iter [60,430] Loss:0.7041, average_loss: 0.5254
# Epoch [8/15], Iter [70,430] Loss:0.8017, average_loss: 0.5469
# Epoch [8/15], Iter [80,430] Loss:0.3935, average_loss: 0.5524
# Epoch [8/15], Iter [90,430] Loss:0.8291, average_loss: 0.5658
# Epoch [8/15], Iter [100,430] Loss:0.9936, average_loss: 0.5768
# Epoch [8/15], Iter [110,430] Loss:0.7216, average_loss: 0.5858
# Epoch [8/15], Iter [120,430] Loss:1.0167, average_loss: 0.5921
# Epoch [8/15], Iter [130,430] Loss:0.4860, average_loss: 0.5892
# Epoch [8/15], Iter [140,430] Loss:0.5085, average_loss: 0.5864
# Epoch [8/15], Iter [150,430] Loss:0.3546, average_loss: 0.5859
# Epoch [8/15], Iter [160,430] Loss:0.4108, average_loss: 0.5853
# Epoch [8/15], Iter [170,430] Loss:0.6885, average_loss: 0.5933
# Epoch [8/15], Iter [180,430] Loss:0.6298, average_loss: 0.5975
# Epoch [8/15], Iter [190,430] Loss:0.4383, average_loss: 0.6006
# Epoch [8/15], Iter [200,430] Loss:0.5489, average_loss: 0.5977
# Epoch [8/15], Iter [210,430] Loss:0.4900, average_loss: 0.5963
# Epoch [8/15], Iter [220,430] Loss:0.6158, average_loss: 0.5949
# Epoch [8/15], Iter [230,430] Loss:0.6544, average_loss: 0.5942
# Epoch [8/15], Iter [240,430] Loss:0.5447, average_loss: 0.5941
# Epoch [8/15], Iter [250,430] Loss:0.5449, average_loss: 0.5903
# Epoch [8/15], Iter [260,430] Loss:0.5624, average_loss: 0.5874
# Epoch [8/15], Iter [270,430] Loss:0.6418, average_loss: 0.5879
# Epoch [8/15], Iter [280,430] Loss:0.5320, average_loss: 0.5873
# Epoch [8/15], Iter [290,430] Loss:0.5204, average_loss: 0.5907
# Epoch [8/15], Iter [300,430] Loss:0.4204, average_loss: 0.5904
# Epoch [8/15], Iter [310,430] Loss:0.7637, average_loss: 0.5909
# Epoch [8/15], Iter [320,430] Loss:0.4279, average_loss: 0.5905
# Epoch [8/15], Iter [330,430] Loss:0.4897, average_loss: 0.5891
# Epoch [8/15], Iter [340,430] Loss:0.2947, average_loss: 0.5900
# Epoch [8/15], Iter [350,430] Loss:0.4973, average_loss: 0.5904
# Epoch [8/15], Iter [360,430] Loss:0.5461, average_loss: 0.5879
# Epoch [8/15], Iter [370,430] Loss:0.6060, average_loss: 0.5905
# Epoch [8/15], Iter [380,430] Loss:1.0307, average_loss: 0.5925
# Epoch [8/15], Iter [390,430] Loss:0.3970, average_loss: 0.5905
# Epoch [8/15], Iter [400,430] Loss:0.5024, average_loss: 0.5879
# Epoch [8/15], Iter [410,430] Loss:0.3745, average_loss: 0.5878
# Epoch [8/15], Iter [420,430] Loss:0.5823, average_loss: 0.5860
# Epoch [8/15], Iter [430,430] Loss:0.4522, average_loss: 0.5835
# Epoch [9/15], Iter [10,430] Loss:0.3500, average_loss: 0.4959
# Epoch [9/15], Iter [20,430] Loss:0.5095, average_loss: 0.6003
# Epoch [9/15], Iter [30,430] Loss:0.4909, average_loss: 0.6069
# Epoch [9/15], Iter [40,430] Loss:0.3045, average_loss: 0.6064
# Epoch [9/15], Iter [50,430] Loss:0.2681, average_loss: 0.5782
# Epoch [9/15], Iter [60,430] Loss:0.2927, average_loss: 0.5811
# Epoch [9/15], Iter [70,430] Loss:0.9593, average_loss: 0.5790
# Epoch [9/15], Iter [80,430] Loss:0.6728, average_loss: 0.5707
# Epoch [9/15], Iter [90,430] Loss:0.4427, average_loss: 0.5654
# Epoch [9/15], Iter [100,430] Loss:0.2928, average_loss: 0.5731
# Epoch [9/15], Iter [110,430] Loss:0.4017, average_loss: 0.5674
# Epoch [9/15], Iter [120,430] Loss:0.5401, average_loss: 0.5654
# Epoch [9/15], Iter [130,430] Loss:0.5190, average_loss: 0.5703
# Epoch [9/15], Iter [140,430] Loss:0.4324, average_loss: 0.5650
# Epoch [9/15], Iter [150,430] Loss:0.9028, average_loss: 0.5595
# Epoch [9/15], Iter [160,430] Loss:0.3740, average_loss: 0.5643
# Epoch [9/15], Iter [170,430] Loss:0.3401, average_loss: 0.5632
# Epoch [9/15], Iter [180,430] Loss:0.4463, average_loss: 0.5603
# Epoch [9/15], Iter [190,430] Loss:0.6380, average_loss: 0.5593
# Epoch [9/15], Iter [200,430] Loss:0.3477, average_loss: 0.5640
# Epoch [9/15], Iter [210,430] Loss:0.4007, average_loss: 0.5579
# Epoch [9/15], Iter [220,430] Loss:0.3166, average_loss: 0.5568
# Epoch [9/15], Iter [230,430] Loss:1.1335, average_loss: 0.5607
# Epoch [9/15], Iter [240,430] Loss:0.3633, average_loss: 0.5612
# Epoch [9/15], Iter [250,430] Loss:0.3844, average_loss: 0.5596
# Epoch [9/15], Iter [260,430] Loss:0.3844, average_loss: 0.5584
# Epoch [9/15], Iter [270,430] Loss:0.3858, average_loss: 0.5578
# Epoch [9/15], Iter [280,430] Loss:0.3037, average_loss: 0.5581
# Epoch [9/15], Iter [290,430] Loss:0.6361, average_loss: 0.5571
# Epoch [9/15], Iter [300,430] Loss:0.3755, average_loss: 0.5573
# Epoch [9/15], Iter [310,430] Loss:0.3434, average_loss: 0.5543
# Epoch [9/15], Iter [320,430] Loss:0.5255, average_loss: 0.5540
# Epoch [9/15], Iter [330,430] Loss:0.4127, average_loss: 0.5531
# Epoch [9/15], Iter [340,430] Loss:0.7274, average_loss: 0.5539
# Epoch [9/15], Iter [350,430] Loss:0.6005, average_loss: 0.5546
# Epoch [9/15], Iter [360,430] Loss:0.4708, average_loss: 0.5562
# Epoch [9/15], Iter [370,430] Loss:0.4793, average_loss: 0.5563
# Epoch [9/15], Iter [380,430] Loss:0.3933, average_loss: 0.5560
# Epoch [9/15], Iter [390,430] Loss:1.2624, average_loss: 0.5592
# Epoch [9/15], Iter [400,430] Loss:0.5865, average_loss: 0.5578
# Epoch [9/15], Iter [410,430] Loss:0.5023, average_loss: 0.5569
# Epoch [9/15], Iter [420,430] Loss:0.5646, average_loss: 0.5557
# Epoch [9/15], Iter [430,430] Loss:1.0465, average_loss: 0.5586
# Epoch [10/15], Iter [10,430] Loss:0.5781, average_loss: 0.5283
# Epoch [10/15], Iter [20,430] Loss:0.5998, average_loss: 0.5958
# Epoch [10/15], Iter [30,430] Loss:0.5035, average_loss: 0.5902
# Epoch [10/15], Iter [40,430] Loss:0.3943, average_loss: 0.5680
# Epoch [10/15], Iter [50,430] Loss:0.3586, average_loss: 0.5803
# Epoch [10/15], Iter [60,430] Loss:1.2126, average_loss: 0.5827
# Epoch [10/15], Iter [70,430] Loss:0.4278, average_loss: 0.5758
# Epoch [10/15], Iter [80,430] Loss:0.7152, average_loss: 0.5804
# Epoch [10/15], Iter [90,430] Loss:0.7005, average_loss: 0.5876
# Epoch [10/15], Iter [100,430] Loss:0.8939, average_loss: 0.5858
# Epoch [10/15], Iter [110,430] Loss:0.9751, average_loss: 0.5951
# Epoch [10/15], Iter [120,430] Loss:0.5718, average_loss: 0.5939
# Epoch [10/15], Iter [130,430] Loss:0.3836, average_loss: 0.5886
# Epoch [10/15], Iter [140,430] Loss:0.3360, average_loss: 0.5829
# Epoch [10/15], Iter [150,430] Loss:0.5242, average_loss: 0.5758
# Epoch [10/15], Iter [160,430] Loss:0.7978, average_loss: 0.5755
# Epoch [10/15], Iter [170,430] Loss:0.3996, average_loss: 0.5763
# Epoch [10/15], Iter [180,430] Loss:0.4485, average_loss: 0.5744
# Epoch [10/15], Iter [190,430] Loss:0.4332, average_loss: 0.5720
# Epoch [10/15], Iter [200,430] Loss:0.4289, average_loss: 0.5737
# Epoch [10/15], Iter [210,430] Loss:0.4068, average_loss: 0.5711
# Epoch [10/15], Iter [220,430] Loss:0.4092, average_loss: 0.5733
# Epoch [10/15], Iter [230,430] Loss:0.3831, average_loss: 0.5717
# Epoch [10/15], Iter [240,430] Loss:0.5511, average_loss: 0.5720
# Epoch [10/15], Iter [250,430] Loss:0.4762, average_loss: 0.5730
# Epoch [10/15], Iter [260,430] Loss:0.4325, average_loss: 0.5741
# Epoch [10/15], Iter [270,430] Loss:0.3381, average_loss: 0.5745
# Epoch [10/15], Iter [280,430] Loss:0.4493, average_loss: 0.5726
# Epoch [10/15], Iter [290,430] Loss:0.8082, average_loss: 0.5704
# Epoch [10/15], Iter [300,430] Loss:0.6890, average_loss: 0.5708
# Epoch [10/15], Iter [310,430] Loss:0.7991, average_loss: 0.5704
# Epoch [10/15], Iter [320,430] Loss:0.5422, average_loss: 0.5702
# Epoch [10/15], Iter [330,430] Loss:0.5012, average_loss: 0.5685
# Epoch [10/15], Iter [340,430] Loss:0.5479, average_loss: 0.5667
# Epoch [10/15], Iter [350,430] Loss:1.0662, average_loss: 0.5674
# Epoch [10/15], Iter [360,430] Loss:0.8706, average_loss: 0.5682
# Epoch [10/15], Iter [370,430] Loss:0.7026, average_loss: 0.5751
# Epoch [10/15], Iter [380,430] Loss:0.3586, average_loss: 0.5770
# Epoch [10/15], Iter [390,430] Loss:0.4194, average_loss: 0.5759
# Epoch [10/15], Iter [400,430] Loss:0.5033, average_loss: 0.5766
# Epoch [10/15], Iter [410,430] Loss:0.7054, average_loss: 0.5748
# Epoch [10/15], Iter [420,430] Loss:0.4392, average_loss: 0.5735
# Epoch [10/15], Iter [430,430] Loss:0.5996, average_loss: 0.5745
# Epoch [11/15], Iter [10,430] Loss:0.3454, average_loss: 0.5354
# Epoch [11/15], Iter [20,430] Loss:0.7738, average_loss: 0.5878
# Epoch [11/15], Iter [30,430] Loss:0.3946, average_loss: 0.5850
# Epoch [11/15], Iter [40,430] Loss:0.6756, average_loss: 0.5918
# Epoch [11/15], Iter [50,430] Loss:0.6142, average_loss: 0.6096
# Epoch [11/15], Iter [60,430] Loss:0.6070, average_loss: 0.5963
# Epoch [11/15], Iter [70,430] Loss:0.4356, average_loss: 0.5865
# Epoch [11/15], Iter [80,430] Loss:0.6116, average_loss: 0.5742
# Epoch [11/15], Iter [90,430] Loss:0.6201, average_loss: 0.5607
# Epoch [11/15], Iter [100,430] Loss:0.3667, average_loss: 0.5559
# Epoch [11/15], Iter [110,430] Loss:0.4322, average_loss: 0.5657
# Epoch [11/15], Iter [120,430] Loss:0.7714, average_loss: 0.5689
# Epoch [11/15], Iter [130,430] Loss:0.7336, average_loss: 0.5721
# Epoch [11/15], Iter [140,430] Loss:0.3780, average_loss: 0.5717
# Epoch [13/15], Iter [130,430] Loss:0.3432, average_loss: 0.5665
# Epoch [13/15], Iter [140,430] Loss:0.9207, average_loss: 0.5732
# Epoch [13/15], Iter [150,430] Loss:0.4663, average_loss: 0.5691
# Epoch [13/15], Iter [160,430] Loss:0.5909, average_loss: 0.5697
# Epoch [13/15], Iter [170,430] Loss:0.4988, average_loss: 0.5753
# Epoch [13/15], Iter [180,430] Loss:0.3800, average_loss: 0.5762
# Epoch [13/15], Iter [190,430] Loss:0.6057, average_loss: 0.5726
# Epoch [13/15], Iter [200,430] Loss:0.8762, average_loss: 0.5754
# Epoch [13/15], Iter [210,430] Loss:0.9624, average_loss: 0.5726
# Epoch [13/15], Iter [220,430] Loss:0.3680, average_loss: 0.5722
# Epoch [13/15], Iter [230,430] Loss:0.6599, average_loss: 0.5687
# Epoch [13/15], Iter [240,430] Loss:0.3882, average_loss: 0.5687
# Epoch [13/15], Iter [250,430] Loss:0.7342, average_loss: 0.5686
# Epoch [13/15], Iter [260,430] Loss:0.5020, average_loss: 0.5708
# Epoch [13/15], Iter [270,430] Loss:0.5589, average_loss: 0.5687
# Epoch [13/15], Iter [280,430] Loss:0.3073, average_loss: 0.5701
# Epoch [13/15], Iter [290,430] Loss:0.3905, average_loss: 0.5719
# Epoch [13/15], Iter [300,430] Loss:0.4447, average_loss: 0.5699
# Epoch [13/15], Iter [310,430] Loss:0.5722, average_loss: 0.5680
# Epoch [13/15], Iter [320,430] Loss:0.3681, average_loss: 0.5668
# Epoch [13/15], Iter [330,430] Loss:0.4798, average_loss: 0.5658
# Epoch [13/15], Iter [340,430] Loss:0.5125, average_loss: 0.5645
# Epoch [13/15], Iter [350,430] Loss:0.4717, average_loss: 0.5634
# Epoch [13/15], Iter [360,430] Loss:0.8642, average_loss: 0.5648
# Epoch [13/15], Iter [370,430] Loss:0.6280, average_loss: 0.5632
# Epoch [13/15], Iter [380,430] Loss:0.4164, average_loss: 0.5611
# Epoch [13/15], Iter [390,430] Loss:0.4915, average_loss: 0.5616
# Epoch [13/15], Iter [400,430] Loss:0.4044, average_loss: 0.5609
# Epoch [13/15], Iter [410,430] Loss:0.5796, average_loss: 0.5608
# Epoch [13/15], Iter [420,430] Loss:0.4100, average_loss: 0.5583
# Epoch [13/15], Iter [430,430] Loss:0.5993, average_loss: 0.5595
# Epoch [14/15], Iter [10,430] Loss:1.4472, average_loss: 0.6129
# Epoch [14/15], Iter [20,430] Loss:0.3361, average_loss: 0.5424
# Epoch [14/15], Iter [30,430] Loss:0.4801, average_loss: 0.5753
# Epoch [14/15], Iter [40,430] Loss:0.2984, average_loss: 0.5737
# Epoch [14/15], Iter [50,430] Loss:0.4141, average_loss: 0.5414
# Epoch [14/15], Iter [60,430] Loss:0.5832, average_loss: 0.5483
# Epoch [14/15], Iter [70,430] Loss:0.2855, average_loss: 0.5504
# Epoch [14/15], Iter [80,430] Loss:0.9899, average_loss: 0.5519
# Epoch [14/15], Iter [90,430] Loss:0.5028, average_loss: 0.5557
# Epoch [14/15], Iter [100,430] Loss:0.3699, average_loss: 0.5595
# Epoch [14/15], Iter [110,430] Loss:0.9215, average_loss: 0.5615
# Epoch [14/15], Iter [120,430] Loss:0.5923, average_loss: 0.5599
# Epoch [14/15], Iter [130,430] Loss:0.4941, average_loss: 0.5560
# Epoch [14/15], Iter [140,430] Loss:0.5841, average_loss: 0.5509
# Epoch [14/15], Iter [150,430] Loss:0.5832, average_loss: 0.5545
# Epoch [14/15], Iter [160,430] Loss:1.0112, average_loss: 0.5568
# Epoch [14/15], Iter [170,430] Loss:0.4280, average_loss: 0.5537
# Epoch [14/15], Iter [180,430] Loss:0.6071, average_loss: 0.5537
# Epoch [14/15], Iter [190,430] Loss:0.4385, average_loss: 0.5516
# Epoch [14/15], Iter [200,430] Loss:0.7663, average_loss: 0.5531
# Epoch [14/15], Iter [210,430] Loss:0.4149, average_loss: 0.5470
# Epoch [14/15], Iter [220,430] Loss:0.8494, average_loss: 0.5462
# Epoch [14/15], Iter [230,430] Loss:0.4568, average_loss: 0.5479
# Epoch [14/15], Iter [240,430] Loss:0.4136, average_loss: 0.5495
# Epoch [14/15], Iter [250,430] Loss:0.3701, average_loss: 0.5511
# Epoch [14/15], Iter [260,430] Loss:0.3442, average_loss: 0.5534
# Epoch [14/15], Iter [270,430] Loss:0.5296, average_loss: 0.5533
# Epoch [14/15], Iter [280,430] Loss:0.4807, average_loss: 0.5559
# Epoch [14/15], Iter [290,430] Loss:0.4985, average_loss: 0.5558
# Epoch [14/15], Iter [300,430] Loss:0.5060, average_loss: 0.5576
# Epoch [14/15], Iter [310,430] Loss:0.9292, average_loss: 0.5607
# Epoch [14/15], Iter [320,430] Loss:0.4038, average_loss: 0.5596
# Epoch [14/15], Iter [330,430] Loss:0.6601, average_loss: 0.5579
# Epoch [14/15], Iter [340,430] Loss:0.6704, average_loss: 0.5567
# Epoch [14/15], Iter [350,430] Loss:0.6003, average_loss: 0.5555
# Epoch [14/15], Iter [360,430] Loss:0.9788, average_loss: 0.5565
# Epoch [14/15], Iter [370,430] Loss:0.5722, average_loss: 0.5572
# Epoch [14/15], Iter [380,430] Loss:0.5108, average_loss: 0.5557
# Epoch [14/15], Iter [390,430] Loss:0.3585, average_loss: 0.5550
# Epoch [14/15], Iter [400,430] Loss:0.3925, average_loss: 0.5531
# Epoch [14/15], Iter [410,430] Loss:0.4199, average_loss: 0.5551
# Epoch [14/15], Iter [420,430] Loss:0.3903, average_loss: 0.5540
# Epoch [14/15], Iter [430,430] Loss:0.8641, average_loss: 0.5553
# Epoch [15/15], Iter [10,430] Loss:0.3196, average_loss: 0.5666
# Epoch [15/15], Iter [20,430] Loss:0.5073, average_loss: 0.5453
# Epoch [15/15], Iter [30,430] Loss:0.6287, average_loss: 0.5402
# Epoch [15/15], Iter [40,430] Loss:0.6484, average_loss: 0.5840
# Epoch [15/15], Iter [50,430] Loss:0.3853, average_loss: 0.5634
# Epoch [15/15], Iter [60,430] Loss:0.2849, average_loss: 0.5808
# Epoch [15/15], Iter [70,430] Loss:0.4879, average_loss: 0.5653
# Epoch [15/15], Iter [80,430] Loss:0.4486, average_loss: 0.5584
# Epoch [15/15], Iter [90,430] Loss:0.3903, average_loss: 0.5464
# Epoch [15/15], Iter [100,430] Loss:0.3418, average_loss: 0.5423
# Epoch [15/15], Iter [110,430] Loss:0.3047, average_loss: 0.5523
# Epoch [15/15], Iter [120,430] Loss:1.1525, average_loss: 0.5587
# Epoch [15/15], Iter [130,430] Loss:0.8696, average_loss: 0.5604
# Epoch [15/15], Iter [140,430] Loss:0.5700, average_loss: 0.5590
# Epoch [15/15], Iter [150,430] Loss:0.5549, average_loss: 0.5536
# Epoch [15/15], Iter [160,430] Loss:1.0436, average_loss: 0.5584
# Epoch [15/15], Iter [170,430] Loss:0.4289, average_loss: 0.5548
# Epoch [15/15], Iter [180,430] Loss:0.3900, average_loss: 0.5484
# Epoch [15/15], Iter [190,430] Loss:0.5381, average_loss: 0.5470
# Epoch [15/15], Iter [200,430] Loss:0.3503, average_loss: 0.5443
# Epoch [15/15], Iter [210,430] Loss:0.3736, average_loss: 0.5434
# Epoch [15/15], Iter [220,430] Loss:0.4920, average_loss: 0.5419
# Epoch [15/15], Iter [230,430] Loss:0.6770, average_loss: 0.5452
# Epoch [15/15], Iter [240,430] Loss:1.1919, average_loss: 0.5498
# Epoch [15/15], Iter [250,430] Loss:0.3687, average_loss: 0.5547
# Epoch [15/15], Iter [260,430] Loss:0.4044, average_loss: 0.5548
# Epoch [15/15], Iter [270,430] Loss:0.5572, average_loss: 0.5534
# Epoch [15/15], Iter [280,430] Loss:0.5159, average_loss: 0.5540
# Epoch [15/15], Iter [290,430] Loss:0.7175, average_loss: 0.5539
# Epoch [15/15], Iter [300,430] Loss:0.8374, average_loss: 0.5574
# Epoch [15/15], Iter [310,430] Loss:0.4529, average_loss: 0.5560
# Epoch [15/15], Iter [320,430] Loss:0.8418, average_loss: 0.5552
# Epoch [15/15], Iter [330,430] Loss:0.3569, average_loss: 0.5540
# Epoch [15/15], Iter [340,430] Loss:0.6534, average_loss: 0.5520
# Epoch [15/15], Iter [350,430] Loss:0.4039, average_loss: 0.5499
# Epoch [15/15], Iter [360,430] Loss:0.3852, average_loss: 0.5477
# Epoch [15/15], Iter [370,430] Loss:0.3488, average_loss: 0.5457
# Epoch [15/15], Iter [380,430] Loss:0.3604, average_loss: 0.5447
# Epoch [15/15], Iter [390,430] Loss:0.3691, average_loss: 0.5421
# Epoch [15/15], Iter [400,430] Loss:0.5952, average_loss: 0.5392
# Epoch [15/15], Iter [410,430] Loss:0.5707, average_loss: 0.5387
# Epoch [15/15], Iter [420,430] Loss:0.8024, average_loss: 0.5395
# Epoch [15/15], Iter [430,430] Loss:0.4007, average_loss: 0.5389

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image

import sys, os
sys.path.insert(0, os.path.abspath(".."))

from lab2.utils.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])

    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]

    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)

    plt.imshow(img)

model.eval()
visualize(model, '../lab2/utils/Generate_dataset/images/003033.jpg')

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ../lab2/utils/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs = interpret_target(pred, 0)

    os.makedirs('./predicted', exist_ok=True)
    txt_file = open('./predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()

import glob

model.eval()
img_names = glob.glob('../lab2/utils/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500

# %%
# %run ../lab2/utils/Generate_dataset/main.py
# Out:
# 63.10% = aeroplane AP
# 65.38% = bicycle AP
# 68.72% = bus AP
# 68.68% = car AP
# 77.10% = cat AP
# 73.72% = dog AP
# mAP = 69.45%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
